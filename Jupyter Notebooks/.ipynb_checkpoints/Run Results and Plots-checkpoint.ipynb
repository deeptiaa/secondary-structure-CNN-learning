# %% [markdown]
# # Run Results and Plots

# %%
# import statements
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import re
from matplotlib import pylab
from scipy.stats import sem

# %% [markdown]
# ## Pab1

# %% [markdown]
# #### Network Parameters

# %% [markdown]
# ```python
# model = tf.keras.Sequential([
#     tf.keras.layers.Input(batch_input_shape=input_shape),
#     tf.keras.layers.Conv1D(128, 17, strides=1, padding='valid', activation=tf.nn.leaky_relu),
#     tf.keras.layers.Conv1D(128, 17, strides=1, padding='valid', activation=tf.nn.leaky_relu),
#     tf.keras.layers.Conv1D(128, 17, strides=1, padding='valid', activation=tf.nn.leaky_relu),
#
#     tf.keras.layers.Flatten(),
#
#     tf.keras.layers.Dense(100, activation=tf.nn.leaky_relu),
#     tf.keras.layers.Dropout(0.2),
#     tf.keras.layers.Dense(1)
# ])
# ```

# %% [markdown]
# NOTE: Graphs from 4000 vals

# %%
path = "../Performance data/" + 'last_loss_curve.txt'
last_loss_file = open(path, 'r')
loss_data = last_loss_file.read()
loss_data = loss_data.replace('[', "")
loss_data = loss_data.replace(']', "")
last_loss_curve_list = loss_data.split(', ')

last_loss_file.close()

print(len(last_loss_curve_list))
loss_floats = [float(x) for x in last_loss_curve_list]
loss_floats_small = loss_floats[0:501]
print(len(loss_floats_small))
# Out:
# 3000
# 501

# %%
path = "../Performance data/" + 'last_val_loss_curve.txt'
last_val_loss_file = open(path, 'r')
last_val_loss_data = last_val_loss_file.read()
last_val_loss_data = last_val_loss_data.replace('[', "")
last_val_loss_data = last_val_loss_data.replace(']', "")
last_val_loss_curve_list = last_val_loss_data.split(', ')

last_val_loss_file.close()

print(len(last_val_loss_curve_list))
val_loss_floats = [float(x) for x in last_val_loss_curve_list]
val_loss_floats_small = val_loss_floats[0:501]
# Out:
# 3000

# %%
plt.semilogy(loss_floats_small) 
plt.semilogy(val_loss_floats_small)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.semilogy(loss_floats) 
plt.semilogy(val_loss_floats)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(loss_floats) 
plt.plot(val_loss_floats)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(loss_floats_small) 
plt.plot(val_loss_floats_small)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
print(min(last_loss_curve_list))
print(max(last_val_loss_curve_list))
# Out:
# 0.0003345049626659602
# 0.03635396808385849

# %%
path = "../Performance data/" + 'pred.txt'
pred_file = open(path, 'r')
pred_data = pred_file.read()
pred_data = pred_data.replace('[', "")
pred_data = pred_data.replace(']', "")
pred_list = pred_data.split(', ')

pred_file.close()

print(len(pred_list))
pred_list_floats = [float(x) for x in pred_list]
# Out:
# 768

# %%
path = "../Performance data/" + 'best_targets.txt'
best_targets_file = open(path, 'r')
best_targets_data = best_targets_file.read()

paren_start_ind = best_targets_data.index('[')
paren_end_ind = best_targets_data.index(']')

best_targets_data = best_targets_data[paren_start_ind + 1:paren_end_ind]
best_targets_list = best_targets_data.split()

best_targets_file.close()

print(len(best_targets_list))
best_targets_list_float = [float(x) for x in best_targets_list]
# Out:
# 768

# %%
plt.title("Pab1")
plt.scatter(pred_list_floats, best_targets_list_float)
plt.plot([0, 1], [0, 1])
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.savefig("Pab1.png")
plt.show()

# %% [markdown]
# #### Running on Full Dataset (37680)

# %% [markdown]
# Pearson r (p): (0.9278509551494812, 0.0)

# %%
path = "../Performance data/" + 'last_loss_curve_pab1.txt'
last_loss_file = open(path, 'r')
loss_data = last_loss_file.read()
loss_data = loss_data.replace('[', "")
loss_data = loss_data.replace(']', "")
last_loss_curve_list = loss_data.split(', ')

last_loss_file.close()

print(len(last_loss_curve_list))
loss_floats = [float(x) for x in last_loss_curve_list]
# Out:
# 100

# %%
path = "../Performance data/" + 'last_val_loss_curve_pab1.txt'
last_val_loss_file = open(path, 'r')
last_val_loss_data = last_val_loss_file.read()
last_val_loss_data = last_val_loss_data.replace('[', "")
last_val_loss_data = last_val_loss_data.replace(']', "")
last_val_loss_curve_list = last_val_loss_data.split(', ')

last_val_loss_file.close()

print(len(last_val_loss_curve_list))
val_loss_floats = [float(x) for x in last_val_loss_curve_list]
# Out:
# 100

# %%
plt.semilogy(loss_floats) 
plt.semilogy(val_loss_floats)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(loss_floats) 
plt.plot(val_loss_floats)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
path = "../Performance data/" + 'pred_pab1.txt'
pred_file = open(path, 'r')
pred_data = pred_file.read()
pred_data = pred_data.replace('[', "")
pred_data = pred_data.replace(']', "")
pred_list = pred_data.split(', ')

pred_file.close()

print(len(pred_list))
pred_list_floats = [float(x) for x in pred_list]
# Out:
# 7536

# %%
path = "../Performance data/" + 'best_targets_pab1.txt'
best_targets_file = open(path, 'r')
best_targets_data = best_targets_file.read()

paren_start_ind = best_targets_data.index('[')
paren_end_ind = best_targets_data.index(']')

best_targets_data = best_targets_data[paren_start_ind + 1:paren_end_ind]
best_targets_list = best_targets_data.split()

best_targets_file.close()

print(len(best_targets_list))
best_targets_list_float = [float(x) for x in best_targets_list]
# Out:
# 7
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19400/1981846057.py in <module>
#      12
#      13 print(len(best_targets_list))
# ---> 14 best_targets_list_float = [float(x) for x in best_targets_list]
#
# ~\AppData\Local\Temp/ipykernel_19400/1981846057.py in <listcomp>(.0)
#      12
#      13 print(len(best_targets_list))
# ---> 14 best_targets_list_float = [float(x) for x in best_targets_list]
#
# ValueError: could not convert string to float: '...'

# %%
plt.scatter(pred_list_floats, best_targets_list_float)
plt.plot([0, 1], [0, 1])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# ## Ube4b

# %% [markdown]
# #### Network Parameters

# %% [markdown]
# batch size = 64 // graphs for 3200 vals

# %% [markdown]
# ```python
# model = tf.keras.Sequential([
#     tf.keras.layers.Input(batch_input_shape=input_shape),
#     tf.keras.layers.Conv1D(32, 17, strides=1, padding='valid', activation=tf.nn.leaky_relu),
#
#     tf.keras.layers.Flatten(),
#
#     tf.keras.layers.Dense(100, activation=tf.nn.leaky_relu),
#     tf.keras.layers.Dropout(0.2),
#     tf.keras.layers.Dense(1)
# ])
# ```

# %%
path = "../Performance data/" + 'last_loss_curve_ube4b.txt'
last_loss_file = open(path, 'r')
loss_data = last_loss_file.read()
loss_data = loss_data.replace('[', "")
loss_data = loss_data.replace(']', "")
last_loss_curve_list = loss_data.split(', ')

last_loss_file.close()

print(len(last_loss_curve_list))
loss_floats = [float(x) for x in last_loss_curve_list]
loss_floats_small = loss_floats[0:300]
print(len(loss_floats_small))
# Out:
# 3000
# 300

# %%
path = "../Performance data/" + 'last_val_loss_curve_ube4b.txt'
last_val_loss_file = open(path, 'r')
last_val_loss_data = last_val_loss_file.read()
last_val_loss_data = last_val_loss_data.replace('[', "")
last_val_loss_data = last_val_loss_data.replace(']', "")
last_val_loss_curve_list = last_val_loss_data.split(', ')

last_val_loss_file.close()

print(len(last_val_loss_curve_list))
val_loss_floats = [float(x) for x in last_val_loss_curve_list]
val_loss_floats_small = val_loss_floats[0:300]
# Out:
# 3000

# %%
plt.semilogy(loss_floats_small) 
plt.semilogy(val_loss_floats_small)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.semilogy(loss_floats) 
plt.semilogy(val_loss_floats)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(loss_floats) 
plt.plot(val_loss_floats)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(loss_floats_small) 
plt.plot(val_loss_floats_small)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
path = "../Performance data/" + 'pred_ube4b.txt'
pred_file = open(path, 'r')
pred_data = pred_file.read()
pred_data = pred_data.replace('[', "")
pred_data = pred_data.replace(']', "")
pred_list = pred_data.split(', ')

pred_file.close()

print(len(pred_list))
pred_list_floats = [float(x) for x in pred_list]
# Out:
# 640

# %%
path = "../Performance data/" + 'best_targets_ube4b.txt'
best_targets_file = open(path, 'r')
best_targets_data = best_targets_file.read()

paren_start_ind = best_targets_data.index('[')
paren_end_ind = best_targets_data.index(']')

best_targets_data = best_targets_data[paren_start_ind + 1:paren_end_ind]
best_targets_list = best_targets_data.split()

best_targets_file.close()

print(len(best_targets_list))
best_targets_list_float = [float(x) for x in best_targets_list]
# Out:
# 640

# %%
plt.title("Ube4b")
plt.scatter(pred_list_floats, best_targets_list_float)
plt.plot([0, 1], [0, 1])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.savefig("Ube4b.png")
plt.show()

# %% [markdown]
# ## Bgl3

# %% [markdown]
# #### Network Parameters

# %% [markdown]
# batch size = 128 // graphs for 1280 vals

# %% [markdown]
# ```python
# model = tf.keras.Sequential([
#     tf.keras.layers.Input(batch_input_shape=input_shape),
#     tf.keras.layers.Conv1D(128, 3, strides=1, padding='valid', activation=tf.nn.leaky_relu),
#     tf.keras.layers.Conv1D(128, 3, strides=1, padding='valid', activation=tf.nn.leaky_relu),
#     tf.keras.layers.Conv1D(128, 3, strides=1, padding='valid', activation=tf.nn.leaky_relu),
#
#     tf.keras.layers.Flatten(),
#
#     tf.keras.layers.Dense(100, activation=tf.nn.leaky_relu),
#     tf.keras.layers.Dropout(0.2),
#     tf.keras.layers.Dense(1)
# ])
# ```

# %%
path = "../Performance data/" + 'last_loss_curve_bgl3.txt'
last_loss_bgl3_file = open(path, 'r')
loss_data_bgl3 = last_loss_bgl3_file.read()
loss_data_bgl3 = loss_data_bgl3.replace('[', "")
loss_data_bgl3 = loss_data_bgl3.replace(']', "")
last_loss_curve_list_bgl3 = loss_data_bgl3.split(', ')

last_loss_bgl3_file.close()

print(len(last_loss_curve_list_bgl3))
loss_floats = [float(x) for x in last_loss_curve_list_bgl3]
loss_floats_small = loss_floats[0:100]
# Out:
# 3000

# %%
path = "../Performance data/" + 'last_val_loss_curve_bgl3.txt'
last_val_loss_bgl3_file = open(path, 'r')
last_val_loss_data_bgl3 = last_val_loss_bgl3_file.read()
last_val_loss_data_bgl3 = last_val_loss_data_bgl3.replace('[', "")
last_val_loss_data_bgl3 = last_val_loss_data_bgl3.replace(']', "")
last_val_loss_curve_list_bgl3 = last_val_loss_data_bgl3.split(', ')

last_val_loss_bgl3_file.close()

print(len(last_val_loss_curve_list_bgl3))
val_loss_floats = [float(x) for x in last_val_loss_curve_list_bgl3]
val_loss_floats_small = val_loss_floats[0:100]
# Out:
# 3000

# %%
plt.semilogy(loss_floats) 
plt.semilogy(val_loss_floats)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
type(min(last_val_loss_curve_list_bgl3))
type(max(last_val_loss_curve_list_bgl3))
# Out:
# str

# %%
plt.plot(loss_floats_small) 
plt.plot(val_loss_floats_small)
# plt.yticks(np.arange(min(val_loss_floats), max(val_loss_floats)+1, 100))
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(loss_floats) 
plt.plot(val_loss_floats)
# plt.yticks(np.arange(min(val_loss_floats), max(val_loss_floats)+1, 100))
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
path = "../Performance data/" + 'pred_bgl3.txt'
pred_bgl3_file = open(path, 'r')
pred_data_bgl3 = pred_bgl3_file.read()
pred_data_bgl3 = pred_data_bgl3.replace('[', "")
pred_data_bgl3 = pred_data_bgl3.replace(']', "")
pred_list_bgl3 = pred_data_bgl3.split(', ')

pred_bgl3_file.close()

print(len(pred_list_bgl3))
pred_list_bgl3_floats = [float(x) for x in pred_list_bgl3]
# Out:
# 256

# %%
path = "../Performance data/" + 'best_targets_bgl3.txt'
best_targets_bgl3_file = open(path, 'r')
best_targets_data_bgl3 = best_targets_bgl3_file.read()

paren_start_ind = best_targets_data_bgl3.index('[')
paren_end_ind = best_targets_data_bgl3.index(']')

best_targets_data_bgl3 = best_targets_data_bgl3[paren_start_ind + 1:paren_end_ind]
best_targets_list_bgl3 = best_targets_data_bgl3.split()

best_targets_bgl3_file.close()

print(len(best_targets_list_bgl3))
best_targets_list_bgl3_floats = [float(x) for x in best_targets_list_bgl3]
# Out:
# 256

# %%
plt.title("Bgl3")
plt.scatter(pred_list_bgl3_floats, best_targets_list_bgl3_floats)
plt.plot([0, 1], [0, 1])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.savefig("Bgl3.png")
plt.show()

# %% [markdown]
# Pearson r (p): (0.1016135738, 0.1047901048)

# %% [markdown]
# **Full Dataset (25600) :** Pearson r (p): (0.5357302086519845, 0.0)

# %% [markdown]
# Graphs for Full Dataset
# (Files)
# - last_loss_curve_bgl_128_all.txt
# - last_val_loss_curve_bgl_128_all.txt
# - pred_bgl_128_all.txt
# - best_targets_bgl_128_all.txt
# - predictor_clean.py_bgl_config

# %%
path = "../Performance data/" + 'last_loss_curve_bgl_128_all.txt'
last_loss_bgl3_file = open(path, 'r')
loss_data_bgl3 = last_loss_bgl3_file.read()
loss_data_bgl3 = loss_data_bgl3.replace('[', "")
loss_data_bgl3 = loss_data_bgl3.replace(']', "")
last_loss_curve_list_bgl3 = loss_data_bgl3.split(', ')

last_loss_bgl3_file.close()

print(len(last_loss_curve_list_bgl3))
loss_floats = [float(x) for x in last_loss_curve_list_bgl3]
# Out:
# 100

# %%
path = "../Performance data/" + 'last_val_loss_curve_bgl_128_all.txt'
last_val_loss_bgl3_file = open(path, 'r')
last_val_loss_data_bgl3 = last_val_loss_bgl3_file.read()
last_val_loss_data_bgl3 = last_val_loss_data_bgl3.replace('[', "")
last_val_loss_data_bgl3 = last_val_loss_data_bgl3.replace(']', "")
last_val_loss_curve_list_bgl3 = last_val_loss_data_bgl3.split(', ')

last_val_loss_bgl3_file.close()

print(len(last_val_loss_curve_list_bgl3))
val_loss_floats = [float(x) for x in last_val_loss_curve_list_bgl3]
# Out:
# 100

# %%
plt.semilogy(loss_floats) 
plt.semilogy(val_loss_floats)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(loss_floats) 
plt.plot(val_loss_floats)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
path = "../Performance data/" + 'pred_bgl_128_all.txt'
pred_bgl3_file = open(path, 'r')
pred_data_bgl3 = pred_bgl3_file.read()
pred_data_bgl3 = pred_data_bgl3.replace('[', "")
pred_data_bgl3 = pred_data_bgl3.replace(']', "")
pred_list_bgl3 = pred_data_bgl3.split(', ')

pred_bgl3_file.close()

print(len(pred_list_bgl3))
pred_list_bgl3_floats = [float(x) for x in pred_list_bgl3]
# Out:
# 5120

# %%
path = "../Performance data/" + 'best_targets_bgl_128_all.txt'
best_targets_bgl3_file = open(path, 'r')
best_targets_data_bgl3 = best_targets_bgl3_file.read()

paren_start_ind = best_targets_data_bgl3.index('[')
paren_end_ind = best_targets_data_bgl3.index(']')

best_targets_data_bgl3 = best_targets_data_bgl3[paren_start_ind + 1:paren_end_ind]
best_targets_list_bgl3 = best_targets_data_bgl3.split()

best_targets_bgl3_file.close()

print(len(best_targets_list_bgl3))
best_targets_list_bgl3_floats = [float(x) for x in best_targets_list_bgl3]
# Out:
# 7
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19400/3715647186.py in <module>
#      12
#      13 print(len(best_targets_list_bgl3))
# ---> 14 best_targets_list_bgl3_floats = [float(x) for x in best_targets_list_bgl3]
#
# ~\AppData\Local\Temp/ipykernel_19400/3715647186.py in <listcomp>(.0)
#      12
#      13 print(len(best_targets_list_bgl3))
# ---> 14 best_targets_list_bgl3_floats = [float(x) for x in best_targets_list_bgl3]
#
# ValueError: could not convert string to float: '...'

# %%
plt.scatter(pred_list_bgl3_floats, best_targets_list_bgl3_floats)
plt.plot([0, 1], [0, 1])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# Graph of Network Accuracy and Secondary Structure Correlation

# %%
y = [(0.9129302028345139, 0.9115976038508473), (0.5585845275740082, 0.5434219516146193), (0.457217374540003, 0.43648093077672195)]

# %%
plt.rcParams["figure.figsize"] = [5.2, 5.2]
plt.rcParams["figure.autolayout"] = True

labels = ['Bgl3', 'Pab1', 'Ube4b']
sec_str = [0.45, 0.91, 0.56]
no_sec_str = [0.43, 0.91, 0.54]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, sec_str, width, label='In Sec Str', )
rects2 = ax.bar(x + width/2, no_sec_str, width, label='Not in Sec Str')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Pearson\'s R Correlation Coefficient', fontsize=13)
ax.set_xlabel('Protein', fontsize=13)
ax.set_title('Network Accuracy and Secondary Structure Correlation', y=1.02, fontsize=16)
ax.set_xticks(x)
ax.set_xticklabels(labels, y=0.03)
ax.legend()

ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

fig.tight_layout()

plt.savefig('Sec Struc Graph.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# - last_loss_curve_pab1_not_ss_3000.txt
# - last_val_loss_curve_pab1_not_ss_3000.txt
# - pred_pab1_not_ss_3000.txt
# - best_targets_pab1_not_ss_3000.txt

# %% [markdown]
# ## Pearson's R Values for Different Runs

# %% [markdown]
# ### Full Dataset:

# %% [markdown]
# - Pab1 (37680 vals): Pearson r (p): (**0.9278509551494812**, 0.0)
#     - _Gelman et al._: ~0.92

# %% [markdown]
# - Bgl3 (25600 vals): Pearson r (p): (**0.5357302086519845**, 0.0)
#     - _Gelman et al._: ~0.58

# %% [markdown]
# - Ube4b (90960 vals): Pearson r (p): (**0.6305278833539137**, 0.0)
#     - _Gelman et al._: ~0.68

# %% [markdown]
# ### 2880 Values Tested On _Gelman et al._ model architecture

# %% [markdown]
# **Pab1**

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (**0.9129302028345139**, 1.4168940610261693e-225)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (**0.9115976038508473**, 9.0846075986949e-224)

# %% [markdown]
# **Ube4b**

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (**0.5585845275740082**, 1.4401906991773618e-48)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (**0.5434219516146193**, 1.4497419352709792e-45)

# %% [markdown]
# **Bgl3**

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (**0.457217374540003**, 4.251033312898647e-31)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (**0.43648093077672195**, 3.427813991841695e-28)

# %% [markdown]
# ### 2880 Values with Limited Mutations (Sec Str. & Non Sec Str. Range Equal) Tested On _Gelman et al._ model architecture

# %% [markdown]
# **Pab1**

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (**0.9122610769070298**, 1.1541336317220239e-224)

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (0.8972997138080814, 5.191046622233254e-206)

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (0.9052302110180326, 1.6389134323677254e-215)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (**0.9234782002494057**, 5.44665457540902e-241)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (0.9311604797245364, 1.1027686591900244e-253)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (0.9345283829320846, 1.0136289359724669e-259)

# %% [markdown]
# **Bgl3**

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (**0.5111021371371963**, 1.1874422546863528e-39)

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (0.5165493376932311, 1.324442906629164e-40)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (**0.48319936881799785**, 4.939742434333919e-35)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (0.40674988493101083, 2.3267421742509385e-24)

# %% [markdown]
# **Ube4b**

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (**0.631371008711717**, 2.161223243468508e-65)

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (0.5593810899192226, 9.91665995533565e-49)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (**0.464103160997065**, 4.152891568475408e-32)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (0.4589589785480639, 2.372302390954809e-31)

# %% [markdown]
# ### 2880 Values with Grouped Limited Mutations (Sec Str. & Non Sec Str. Range Equal) Tested On _Gelman et al._ model architecture

# %% [markdown]
# **Pab1**

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (**0.9276710959443086**, 9.588313674002012e-248)

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (**0.9241855287752498**, 4.208581416732965e-242)

# %% [markdown]
# - In Secondary Structure (**1440 vals**): Pearson r (p): (**0.9136751921711617**, 7.706156560097807e-114)

# %% [markdown]
# - In Secondary Structure (**800 vals**): Pearson r (p): (**0.8920308137218321**, 1.2168023735431704e-100)

# %% [markdown]
# - In Secondary Structure (**800 vals**): Pearson r (p): (**0.848765120486074**, 1.4068641457552015e-45)

# %% [markdown]
# - In Secondary Structure (**800 vals**): Pearson r (p): (**0.8070787357436985**, 5.492679849218799e-38)

# %% [markdown]
# - In Secondary Structure (**800 vals**): Pearson r (p): (0.7860898742679926, 7.82396763335842e-35)

# %% [markdown]
# - In Secondary Structure (**480 vals**): Pearson r (p): (**0.7114152684486137**, 4.553435195383389e-16)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (**0.9222569281091366**, 4.276608773697753e-239)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (**0.9372470666849644**, 7.823516260439053e-265)

# %% [markdown]
# - NOT in Secondary Structure (**1440 vals**): Pearson r (p): (**0.9207307794610452**, 6.556005554098434e-119)

# %% [markdown]
# - NOT in Secondary Structure (**800 vals**): Pearson r (p): (**0.8314969015345953**, 3.5040686826551445e-42)

# %% [markdown]
# - In Secondary Structure (**800 vals**): Pearson r (p): (**0.8440369572119651**, 1.315188822714307e-44)

# %% [markdown]
# - In Secondary Structure (**800 vals**): Pearson r (p): (**0.8979731026991387**, 3.3218918700126365e-58)

# %% [markdown]
# - In Secondary Structure (**800 vals**): Pearson r (p): (0.8887187624101511, 2.1726546627801504e-55)

# %% [markdown]
# - NOT in Secondary Structure (**480 vals**): Pearson r (p): (**0.8501436488216698**, 6.286346426598072e-28)

# %% [markdown]
# **Bgl3**

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (**0.45188081848987843**, 2.487100781945728e-30)

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (**0.5169843188580168**, 1.1097390487317827e-40)

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (**0.5159605453924065**, 1.6820164118059239e-40)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (**0.35373652623638113**, 2.0246617479133915e-18)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (**0.4413174149001031**, 7.497023006977138e-29)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (**0.4417344732161629**, 6.568498803662338e-29)

# %% [markdown]
# **In Secondary Stucture Avg:** 0.4949

# %% [markdown]
# **Not in Secondary Structure Avg:** 0.4122

# %% [markdown]
# **Ube4b**

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (**0.6270872436356196**, 2.8183842488969387e-64)

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (**0.6040213399843402**, 1.46910164929479e-58)

# %% [markdown]
# - In Secondary Structure: Pearson r (p): (**0.5325095807823053**, 1.696563121106269e-43)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (**0.5127574983112341**, 6.122793229385368e-40)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (**0.5328054262851161**, 1.4944718267378188e-43)

# %% [markdown]
# - NOT in Secondary Structure: Pearson r (p): (**0.46716077918721327**, 1.4533683171208467e-32)

# %% [markdown]
# **In Secondary Stucture Avg:** 0.5878

# %% [markdown]
# **Not in Secondary Structure Avg:** 0.5042

# %% [markdown]
# ## Second Round of Part 1 Results (9/7):

# %% [markdown]
# **Goal:** Tested values _in_ secondary structure versus values _not_ in secondary structure to see if there was an effect on Pearson's R value.

# %% [markdown]
# **Setup**:
# - Tested on Pab1, Bgl3, Ube4b
# - Random 900 value test set for each protein (both for in sec. str. and out of sec. str)
# - Use 500, 1000, 2000, 3000 value training sets to invalidate possibility that training data size impacts results

# %% [markdown]
# ## Pab1

# %% [markdown]
# - In SS (**50 vals**): Pearson r (p): (0.5483474701327399, 1.4255125523328354e-79)
# - In SS (**50 vals**): Pearson r (p): (0.5162281437764307, 3.352805656629164e-69)
# - In SS (**50 vals**): Pearson r (p): (0.5200317491523403, 2.2625174849714493e-70)

# %% [markdown]
# - NOT in SS (**50 vals**): Pearson r (p): (0.7090554774230347, 1.3732953233566673e-153)
# - NOT in SS (**50 vals**): Pearson r (p): (0.670192849563849, 2.2276766582781288e-131)
# - NOT in SS (**50 vals**): Pearson r (p): (0.6402662806654047, 1.8712831282013504e-116)

# %% [markdown]
# **In Secondary Stucture Avg:**
#
# **Not in Secondary Structure Avg:**

# %% [markdown]
# - In SS (**150 vals**): Pearson r (p): (0.6123649560472132, 5.778828271548108e-104)
# - In SS (**150 vals**): Pearson r (p): (0.590753109436233, 4.078965148283557e-95)
# - In SS (**150 vals**): Pearson r (p): (0.6005213726434372, 4.95141476162229e-99)

# %% [markdown]
# **fixed
# - In SS (**150 vals**): Pearson r (p): (0.7006849034368147, 1.6818253274600315e-148)
# - In SS (**150 vals**):
# - In SS (**150 vals**):

# %% [markdown]
# - NOT in SS (**150 vals**): Pearson r (p): (0.7229845680618286, 1.8056413265420037e-162)
# - NOT in SS (**150 vals**): Pearson r (p): (0.7154149901259281, 1.410341041564534e-157)
# - NOT in SS (**150 vals**): Pearson r (p): (0.7246370637993715, 1.4680806271103125e-163)

# %% [markdown]
# **fixed
# - NOT in SS (**150 vals**): Pearson r (p): (0.753746427373584, 3.664641622520361e-184)
# - NOT in SS (**150 vals**):
# - NOT in SS (**150 vals**):

# %% [markdown]
# **In Secondary Stucture Avg:** 0.600
#
# **Not in Secondary Structure Avg:** 0.720

# %% [markdown]
# - In SS (**500 vals**): Pearson r (p): (0.7679076743542212, 2.9088120033258678e-195)
# - In SS (**500 vals**): Pearson r (p): (0.7478743263667648, 8.863515734247874e-180)
# - In SS (**500 vals**): Pearson r (p): (0.7677805030926372, 3.689009549713708e-195)

# %% [markdown]
# ** fixed again**
#
# - In SS (**500 vals**): Pearson r (p): (0.8759081718446874, 3.716204e-318)
# - In SS (**500 vals**): Pearson r (p): (0.8766251657434021, 2.49335e-319)
# - In SS (**500 vals**): Pearson r (p): (0.8739355361578229, 5.767253926e-315)

# %% [markdown]
# - NOT in SS (**500 vals**): Pearson r (p): (0.8221738765852399, 1.8586499051006285e-246)
# - NOT in SS (**500 vals**): Pearson r (p): (0.8324934084415482, 3.4023589296269944e-258)
# - NOT in SS (**500 vals**): Pearson r (p): (0.8185822902596387, 1.502782784069408e-242)

# %% [markdown]
# ** FIXED AGAIN
# - NOT in SS (**500 vals**): Pearson r (p): (0.8738981148845536, 6.621860064e-315)
# - NOT in SS (**500 vals**): Pearson r (p): (0.8354595991757441, 1.0205298264500686e-261)
# - NOT in SS (**500 vals**): Pearson r (p): (0.8728036558996063, 3.69560516327e-313)

# %%
from statistics import mean
in_ss = round(mean([0.8759081718446874, 0.8766251657434021, 0.8739355361578229]), 3)
print(in_ss)
not_in_ss = round(mean([0.8738981148845536, 0.8354595991757441, 0.8728036558996063]), 3)
print(not_in_ss)

pr = round(mean([0.875, 0.861]), 3)
print(pr)
# Out:
# 0.875
# 0.861
# 0.868

# %% [markdown]
# **In Secondary Stucture Avg:** 0.875
#
# **Not in Secondary Structure Avg:** 0.861
#
# **Diff** 0.014

# %% [markdown]
# - In SS (**1000 vals**): Pearson r (p): (0.8315104977942984, 4.830055491476511e-257)
# - In SS (**1000 vals**): Pearson r (p): (0.8412157619476167, 9.274788145066109e-269)
# - In SS (**1000 vals**): Pearson r (p): (0.8381415096856895, 5.787145952578126e-265)

# %% [markdown]
# - NOT in SS (**1000 vals**): Pearson r (p): (0.8727910114735262, 3.8705328901e-313)
# - NOT in SS (**1000 vals**): Pearson r (p): (0.8724143533972755, 1.53141717525e-312)
# - NOT in SS (**1000 vals**): Pearson r (p): (0.8702351868350455, 4.018109966918007e-309)

# %% [markdown]
# **In Secondary Stucture Avg:** 0.836
#
# **Not in Secondary Structure Avg:** 0.871

# %% [markdown]
# - In SS (**2000 vals**): Pearson r (p): (0.9114588898130753, 0.0)
# - In SS (**2000 vals**): Pearson r (p): (0.9088857183982038, 0.0)
# - In SS (**2000 vals**): Pearson r (p): (0.9059441803498915, 0.0)

# %% [markdown]
# - NOT in SS (**2000 vals**): Pearson r (p): (0.8981362194397369, 0.0)
# - NOT in SS (**2000 vals**): Pearson r (p): (0.9002039072181338, 0.0)
# - NOT in SS (**2000 vals**): Pearson r (p): (0.9083051634255833, 0.0)

# %% [markdown]
# **In Secondary Stucture Avg:** 0.908
#
# **Not in Secondary Structure Avg:** 0.902

# %% [markdown]
# *** NOT ENOUGH VALUES FOR 3000

# %% [markdown]
# ## Bgl3

# %% [markdown]
# **CORRECTED`

# %% [markdown]
# - In SS (**500 vals**): Pearson r (p): (0.3460224328982283, 1.6710321495417845e-29)
# - In SS (**500 vals**): Pearson r (p): (0.3074688350368035, 2.4482937966134777e-23)
# - In SS (**500 vals**): Pearson r (p): (0.41569269005636617, 4.666412792582279e-43)

# %% [markdown]
# - NOT in SS (**500 vals**): Pearson r (p): (0.32520525203516093, 4.5970254073010807e-26)
# - NOT in SS (**500 vals**): Pearson r (p): (0.26016664630808667, 6.203074152553935e-17)
# - NOT in SS (**500 vals**): Pearson r (p): (0.2438212691246391, 5.326125194709482e-15)

# %%
from statistics import mean
in_ss = round(mean([0.3460224328982283, 0.3074688350368035, 0.41569269005636617]), 3)
print(in_ss)
not_in_ss = round(mean([0.32520525203516093, 0.26016664630808667, 0.2438212691246391]), 3)
print(not_in_ss)

pr = round(mean([0.356, 0.276]), 3)
print(pr)
# Out:
# 0.356
# 0.276
# 0.316

# %% [markdown]
# **In Secondary Stucture Avg:** 0.356
#
# **Not in Secondary Structure Avg:** 0.276
#
# **Diff** 0.08

# %% [markdown]
# - In SS (**500 vals**): Pearson r (p): (0.32725463878387695, 2.165252571886817e-26)
# - In SS (**500 vals**): Pearson r (p): (0.31497026174327675, 1.8121392456559258e-24)
# - In SS (**500 vals**): Pearson r (p): (0.2591924504843951, 8.161445463169282e-17)

# %% [markdown]
# - NOT in SS (**500 vals**): Pearson r (p): (0.2897073734957876, 8.669717568597946e-21)
# - NOT in SS (**500 vals**): Pearson r (p): (0.253223870276297, 4.275257692340502e-16)
# - NOT in SS (**500 vals**): Pearson r (p): (0.22807743088034443, 2.8810139612938084e-13)

# %% [markdown]
# **In Secondary Stucture Avg:** 0.300
#
# **Not in Secondary Structure Avg:** 0.256

# %% [markdown]
# - In SS (**1000 vals**): Pearson r (p): (0.41881518678319385, 9.59462814850528e-44)
# - In SS (**1000 vals**): Pearson r (p): (0.4066734948079011, 4.101052381488647e-41)
# - In SS (**1000 vals**): Pearson r (p): (0.3939510223934052, 1.8003402282051323e-38)

# %% [markdown]
# - NOT in SS (**1000 vals**): Pearson r (p): (0.343757527526078, 4.0744436820335994e-29)
# - NOT in SS (**1000 vals**): Pearson r (p): (0.3125816013607555, 4.1856709513014035e-24)
# - NOT in SS (**1000 vals**): Pearson r (p): (0.2984834607566266, 5.020042179474321e-22)

# %% [markdown]
# **In Secondary Stucture Avg:** 0.405
#
# **Not in Secondary Structure Avg:** 0.317

# %% [markdown]
# - In SS (**2000 vals**): Pearson r (p): (0.48722701906383, 9.595069476295418e-61)
# - In SS (**2000 vals**): Pearson r (p): (0.48607088448146657, 2.0072655157169656e-60)
# - In SS (**2000 vals**): Pearson r (p): (0.4692798151632163, 6.643523463114525e-56)

# %% [markdown]
# - NOT in SS (**2000 vals**): Pearson r (p): (0.4010573050014882, 6.216801792407138e-40)
# - NOT in SS (**2000 vals**): Pearson r (p): (0.3977894251722298, 2.952610917635706e-39)
# - NOT in SS (**2000 vals**): Pearson r (p): (0.39844832303844513, 2.159659128807884e-39)

# %% [markdown]
# **In Secondary Stucture Avg:** 0.480
#
# **Not in Secondary Structure Avg:** 0.398

# %% [markdown]
# - In SS (**3000 vals**): Pearson r (p): (0.4894889778959602, 2.245544004857748e-61)
# - In SS (**3000 vals**): Pearson r (p): (0.5001827476406978, 2.016483035195173e-64)
# - In SS (**3000 vals**): Pearson r (p): (0.5152013626567711, 6.901363472478801e-69)

# %% [markdown]
# - NOT in SS (**3000 vals**): Pearson r (p): (0.44159581059736847, 5.568829376548054e-49)
# - NOT in SS (**3000 vals**): Pearson r (p): (0.4227124013436286, 1.301398919929005e-44)
# - NOT in SS (**3000 vals**): Pearson r (p): (0.42745943684391463, 1.1017883820041369e-45)

# %% [markdown]
# **In Secondary Stucture Avg:** 0.501
#
# **Not in Secondary Structure Avg:** 0.430

# %% [markdown]
# ## Ube4b

# %% [markdown]
# **CORRECTED

# %% [markdown]
# - In SS (**500 vals**): Pearson r (p): (0.5513264155969282, 1.3616925790097747e-80)
# - In SS (**500 vals**): Pearson r (p): (0.5047324095823733, 9.44575136251955e-66)
# - In SS (**500 vals**): Pearson r (p): (0.5332721810934515, 1.448837894910298e-74)

# %% [markdown]
# - NOT in SS (**500 vals**): Pearson r (p): (0.3706217128126761, 6.449137406818451e-34)
# - NOT in SS (**500 vals**): Pearson r (p): (0.35219129133354216, 1.420515667150219e-30)
# - NOT in SS (**500 vals**): Pearson r (p): (0.34617794003359603, 1.5714147695937743e-29)

# %%
from statistics import mean
in_ss = round(mean([0.5513264155969282, 0.5047324095823733, 0.5332721810934515]), 3)
print(in_ss)
not_in_ss = round(mean([0.3706217128126761, 0.35219129133354216, 0.34617794003359603]), 3)
print(not_in_ss)

pr = round(mean([0.53, 0.356]), 3)
print(pr)
# Out:
# 0.53
# 0.356
# 0.443

# %% [markdown]
# **In Secondary Stucture Avg:** 0.530
#
# **Not in Secondary Structure Avg:** 0.356
#
# **Diff** 0.174

# %% [markdown]
# - In SS (**500 vals**): Pearson r (p): (0.5232333410168357, 2.2777748072865554e-71)
# - In SS (**500 vals**): Pearson r (p): (0.5217045945132306, 6.83819607604143e-71)
# - In SS (**500 vals**): Pearson r (p): (0.4617233322319567, 5.967498882856171e-54)

# %% [markdown]
# - NOT in SS (**500 vals**): Pearson r (p): (0.4047394290314017, 1.0520657665914809e-40)
# - NOT in SS (**500 vals**): Pearson r (p): (0.3661530141604531, 4.36762567984919e-33)
# - NOT in SS (**500 vals**): Pearson r (p): (0.4042978030450657, 1.303437875257357e-40)

# %% [markdown]
# **In Secondary Stucture Avg:** 0.501
#
# **Not in Secondary Structure Avg:** 0.391

# %% [markdown]
# - In SS (**1000 vals**): Pearson r (p): (0.5615492832256628, 3.586770667587676e-84)
# - In SS (**1000 vals**): Pearson r (p): (0.5790420370486776, 1.35605480317252e-90)
# - In SS (**1000 vals**): Pearson r (p): (0.589930907502952, 8.59140564989274e-95)

# %% [markdown]
# - NOT in SS (**1000 vals**): Pearson r (p): (0.4217451878705807, 2.1419108671175292e-44)
# - NOT in SS (**1000 vals**): Pearson r (p): (0.4564907140202667, 1.2590100430870462e-52)
# - NOT in SS (**1000 vals**): Pearson r (p): (0.4220818980805746, 1.801152708338752e-44)

# %% [markdown]
# **In Secondary Stucture Avg:** 0.576
#
# **Not in Secondary Structure Avg:** 0.433

# %% [markdown]
# - In SS (**2000 vals**): Pearson r (p): (0.6065409617584097, 1.6350691157136642e-101)
# - In SS (**2000 vals**): Pearson r (p): (0.6245423267959916, 2.929162095661675e-109)
# - In SS (**2000 vals**): Pearson r (p): (0.6112820512050229, 1.6656167864648644e-103)

# %% [markdown]
# - NOT in SS (**2000 vals**): Pearson r (p): (0.513044297606382, 3.119695812492533e-68)
# - NOT in SS (**2000 vals**): Pearson r (p): (0.4664594445810648, 3.6075589158882484e-55)
# - NOT in SS (**2000 vals**): Pearson r (p): (0.48564602814192404, 2.6308423943863155e-60)

# %% [markdown]
# **In Secondary Stucture Avg:** 0.613
#
# **Not in Secondary Structure Avg:** 0.488

# %% [markdown]
# - In SS (**3000 vals**): Pearson r (p): (0.6436810651968877, 4.503538329375378e-118)
# - In SS (**3000 vals**): Pearson r (p): (0.6492170213432941, 9.663305518266347e-121)
# - In SS (**3000 vals**): Pearson r (p): (0.6527137072447832, 1.865135960535918e-122)

# %% [markdown]
# - NOT in SS (**3000 vals**): Pearson r (p): (0.49470227259796323, 7.577218997167595e-63)
# - NOT in SS (**3000 vals**): Pearson r (p): (0.47570822859768, 1.3232737795437248e-57)
# - NOT in SS (**3000 vals**): Pearson r (p): (0.5155972108622053, 5.226248121634858e-69)

# %% [markdown]
# **In Secondary Stucture Avg:** 0.648
#
# **Not in Secondary Structure Avg:** 0.494

# %%
# 500 training values, 1000 test values (same test set for each protein)

plt.rcParams["figure.figsize"] = [5.2, 5.2]
plt.rcParams["figure.autolayout"] = True

# data 
pab1_trials_500_ss = [0.7679076743542212, 0.7478743263667648, 0.7677805030926372]
pab1_trials_500_not_ss = [0.8221738765852399, 0.8324934084415482, 0.8185822902596387]
bgl3_trials_500_ss = [0.32725463878387695, 0.31497026174327675, 0.2591924504843951]
bgl3_trials_500_not_ss = [0.2897073734957876, 0.253223870276297, 0.22807743088034443]
ube4b_trials_500_ss = [0.5232333410168357, 0.5217045945132306, 0.4617233322319567]
ube4b_trials_500_not_ss = [0.4047394290314017, 0.3661530141604531, 0.4042978030450657]

# calculating sem
pab1_500_ss_sem = sem(pab1_trials_500_ss) 
pab1_500_not_ss_sem = sem(pab1_trials_500_not_ss)
bgl3_500_ss_sem = sem(bgl3_trials_500_ss)
bgl3_500_not_ss_sem = sem(bgl3_trials_500_not_ss)
ube4b_500_ss_sem = sem(ube4b_trials_500_ss)
ube4b_500_not_ss = sem(ube4b_trials_500_not_ss)

labels = ['Pab1', 'Bgl3', 'Ube4b']
sec_str = [0.760, 0.300, 0.501]
no_sec_str = [0.824, 0.256, 0.391]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, sec_str, width, label='In Sec Str', yerr = [pab1_500_ss_sem, bgl3_500_ss_sem, ube4b_500_ss_sem])
rects2 = ax.bar(x + width/2, no_sec_str, width, label='Not in Sec Str', yerr = [pab1_500_not_ss_sem, bgl3_500_not_ss_sem, ube4b_500_not_ss])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Pearson\'s R Correlation Coefficient', fontsize=15)
# ax.set_xlabel('Protein', fontsize=15)
ax.set_title('500 Training Values', y=1.02, fontsize=15)
ax.set_xticks(x)
ax.set_xticklabels(labels, y=-0.01, fontdict={'fontsize':15})
ax.set_yticks(np.arange(0, 1.1, 0.1))
# ax.tick_params(axis='x', labelsize=8)
ax.legend()


ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

# ax.errorbar(x, y, yerr=None,

fig.tight_layout()

plt.savefig('500 Train.png', bbox_inches='tight')
plt.show()

# %%
# 1000 training values, 1000 test values (same test set for each protein)

plt.rcParams["figure.figsize"] = [5.2, 5.2]
plt.rcParams["figure.autolayout"] = True

# data
pab1_trials_1000_ss = [0.8315104977942984, 0.8412157619476167, 0.8381415096856895]
pab1_trials_1000_not_ss = [0.8727910114735262, 0.8724143533972755, 0.8702351868350455]
bgl3_trials_1000_ss = [0.41881518678319385, 0.4066734948079011, 0.3939510223934052]
bgl3_trials_1000_not_ss = [0.343757527526078, 0.3125816013607555, 0.2984834607566266]
ube4b_trials_1000_ss = [0.5615492832256628, 0.5790420370486776, 0.589930907502952]
ube4b_trials_1000_not_ss = [0.4217451878705807, 0.4564907140202667, 0.4220818980805746]

# calculating sem
pab1_1000_ss_sem = sem(pab1_trials_1000_ss) 
pab1_1000_not_ss_sem = sem(pab1_trials_1000_not_ss)
bgl3_1000_ss_sem = sem(bgl3_trials_1000_ss)
bgl3_1000_not_ss_sem = sem(bgl3_trials_1000_not_ss)
ube4b_1000_ss_sem = sem(ube4b_trials_1000_ss)
ube4b_1000_not_ss = sem(ube4b_trials_1000_not_ss)

labels = ['Pab1', 'Bgl3', 'Ube4b']
sec_str = [0.836, 0.405, 0.576]
no_sec_str = [0.871, 0.317, 0.433]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, sec_str, width, label='In Sec Str', yerr = [pab1_1000_ss_sem, bgl3_1000_ss_sem, ube4b_1000_ss_sem])
rects2 = ax.bar(x + width/2, no_sec_str, width, label='Not in Sec Str', yerr = [pab1_1000_not_ss_sem, bgl3_1000_not_ss_sem, ube4b_1000_not_ss])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Pearson\'s R Correlation Coefficient', fontsize=15)
# ax.set_xlabel('Protein', fontsize=15)
ax.set_title('1000 Training Values', y=1.02, fontsize=15)
ax.set_xticks(x)
ax.set_xticklabels(labels, y=-0.01, fontdict={'fontsize':15})
ax.set_yticks(np.arange(0, 1.1, 0.1))
# ax.tick_params(axis='x', labelsize=8)
ax.legend()

ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

fig.tight_layout()

plt.savefig('1000 Train.png', bbox_inches='tight')
#plt.show()

# %%
# 2000 training values, 1000 test values (same test set for each protein)

plt.rcParams["figure.figsize"] = [5.2, 5.2]
plt.rcParams["figure.autolayout"] = True

labels = ['Pab1', 'Bgl3', 'Ube4b']
sec_str = [0.908, 0.480, 0.613]
no_sec_str = [0.902, 0.398, 0.488]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, sec_str, width, label='In Sec Str')
rects2 = ax.bar(x + width/2, no_sec_str, width, label='Not in Sec Str')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Pearson\'s R Correlation Coefficient', fontsize=15)
# ax.set_xlabel('Protein', fontsize=15)
ax.set_title('2000 Training Values', y=1.02, fontsize=15)
ax.set_xticks(x)
ax.set_xticklabels(labels, y=-0.01, fontdict={'fontsize':15})
# ax.tick_params(axis='x', labelsize=8)
ax.set_yticks(np.arange(0, 1.1, 0.1))
ax.legend()

ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

fig.tight_layout()

plt.savefig('2000 Train.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Additional Trials

# %% [markdown]
# **avGFP**

# %% [markdown]
# - In SS (**500 vals**): Pearson r (p): (0.7887378062744008, 4.092014304324554e-213)
# - In SS (**500 vals**): Pearson r (p): (0.7674212986456389, 7.211610387761657e-195)
# - In SS (**500 vals**): Pearson r (p): (0.7756237596451863, 1.1909873373098514e-201)

# %% [markdown]
# - NOT in SS (**500 vals**): Pearson r (p): (0.7099582940872851, 3.785692623475041e-154)
# - NOT in SS (**500 vals**): Pearson r (p): (0.6845159705174537, 3.691430455833847e-139)
# - NOT in SS (**500 vals**): Pearson r (p): (0.6773233499300859, 3.3864210378386964e-135)

# %%
# calculating mean
from statistics import mean
in_ss = round(mean([0.7887378062744008, 0.7674212986456389, 0.7756237596451863]), 3)
print(in_ss)
not_in_ss = round(mean([0.7099582940872851, 0.6845159705174537, 0.6773233499300859]), 3)
print(not_in_ss)

pr = round(mean([0.777, 0.691]), 3)
print(pr)
# Out:
# 0.777
# 0.691
# 0.734

# %% [markdown]
# **In Secondary Stucture Avg:** 0.777
#
# **Not in Secondary Structure Avg:** 0.691
#
# **Diff** 0.086

# %% [markdown]
# - In SS (**1000 vals**):
# - In SS (**1000 vals**):
# - In SS (**1000 vals**):

# %% [markdown]
# - NOT in SS (**1000 vals**):
# - NOT in SS (**1000 vals**):
# - NOT in SS (**1000 vals**):

# %% [markdown]
# **In Secondary Stucture Avg:**
#
# **Not in Secondary Structure Avg:**

# %% [markdown]
# **GB1**

# %% [markdown]
# - In SS (**500 vals**): Pearson r (p): (0.8849614170116615, 0.0)
# - In SS (**500 vals**): Pearson r (p): (0.9021136377790461, 0.0)
# - In SS (**500 vals**): Pearson r (p): (0.8874164098451491, 0.0)

# %% [markdown]
# - NOT in SS (**500 vals**): Pearson r (p): (0.9276568019820451, 0.0)
# - NOT in SS (**500 vals**): Pearson r (p): (0.9200945773281073, 0.0)
# - NOT in SS (**500 vals**): Pearson r (p): (0.9200039772619646, 0.0)

# %%
# calculating mean
from statistics import mean
in_ss = round(mean([0.8849614170116615, 0.9021136377790461, 0.8874164098451491]), 3)
print(in_ss)
not_in_ss = round(mean([0.9276568019820451, 0.9200945773281073, 0.9200039772619646]), 3)
print(not_in_ss)

pr = round(mean([0.891, 0.923]), 3)
print(pr)
# Out:
# 0.891
# 0.923
# 0.907

# %% [markdown]
# **In Secondary Stucture Avg:** 0.891
#
# **Not in Secondary Structure Avg:** 0.923
#
# **Diff** -0.032

# %% [markdown]
# - In SS (**1000 vals**):
# - In SS (**1000 vals**):
# - In SS (**1000 vals**):

# %% [markdown]
# - NOT in SS (**1000 vals**):
# - NOT in SS (**1000 vals**):
# - NOT in SS (**1000 vals**):

# %% [markdown]
# **In Secondary Stucture Avg:**
#
# **Not in Secondary Structure Avg:**

# %% [markdown]
# - In SS (**2000 vals**):
# - In SS (**2000 vals**):
# - In SS (**2000 vals**):

# %% [markdown]
# - NOT in SS (**2000 vals**):
# - NOT in SS (**2000 vals**):
# - NOT in SS (**2000 vals**):

# %% [markdown]
# **In Secondary Stucture Avg:**
#
# **Not in Secondary Structure Avg:**

# %% [markdown]
# **1nd4**

# %% [markdown]
# - In SS (**500 vals**): Pearson r (p): (0.5118959209870761, 6.934282987296628e-68)
# - In SS (**500 vals**): Pearson r (p): (0.531038176285458, 7.615052342695408e-74)
# - In SS (**500 vals**): Pearson r (p): (0.5207707247759137, 1.3347349904673828e-70)

# %% [markdown]
# - NOT in SS (**500 vals**): Pearson r (p): (0.577589652639925, 4.7901970079555895e-90)
# - NOT in SS (**500 vals**): Pearson r (p): (0.599867410934066, 9.143483832121445e-99)
# - NOT in SS (**500 vals**): Pearson r (p): (0.5617379404966514, 3.0723550181951744e-84)

# %%
# calculating mean
from statistics import mean
in_ss = round(mean([0.5118959209870761, 0.531038176285458, 0.5207707247759137]), 3)
print(in_ss)
not_in_ss = round(mean([0.577589652639925, 0.599867410934066, 0.5617379404966514]), 3)
print(not_in_ss)

pr = round(mean([0.521, 0.58]), 3)
print(pr)
# Out:
# 0.521
# 0.58
# 0.55

# %% [markdown]
# **In Secondary Stucture Avg:** 0.521
#
# **Not in Secondary Structure Avg:** 0.580
#
# **Diff** -0.059

# %% [markdown]
# **4bz3**

# %% [markdown]
# - In SS (**500 vals**): Pearson r (p): (0.6402649581051406, 1.8739689917209702e-116)
# - In SS (**500 vals**): Pearson r (p): (0.6425683986145994, 1.5248246223050525e-117)
# - In SS (**500 vals**): Pearson r (p): (0.6485138314779102, 2.1240615239620668e-120)

# %% [markdown]
# - NOT in SS (**500 vals**): Pearson r (p): (0.73088953855556, 9.32832034205267e-168)
# - NOT in SS (**500 vals**): Pearson r (p): (0.7439423370008551, 6.538171901127408e-177)
# - NOT in SS (**500 vals**): Pearson r (p): (0.7279343416057691, 9.291150929335844e-166)

# %%
# calculating mean
from statistics import mean
in_ss = round(mean([0.6402649581051406, 0.6425683986145994, 0.6485138314779102]), 3)
print(in_ss)
not_in_ss = round(mean([0.73088953855556, 0.7439423370008551, 0.7279343416057691]), 3)
print(not_in_ss)

pr = round(mean([0.644, 0.734]), 3)
print(pr)
# Out:
# 0.644
# 0.734
# 0.689

# %% [markdown]
# **In Secondary Stucture Avg:** 0.644
#
# **Not in Secondary Structure Avg:** 0.734
#
# **Diff** -0.09

# %% [markdown]
# **3dqw**

# %% [markdown]
# - In SS (**500 vals**):
# - In SS (**500 vals**):
# - In SS (**500 vals**):

# %% [markdown]
# - NOT in SS (**500 vals**):
# - NOT in SS (**500 vals**):
# - NOT in SS (**500 vals**):

# %% [markdown]
# **In Secondary Stucture Avg:**
#
# **Not in Secondary Structure Avg:**

# %% [markdown]
# - In SS (**1000 vals**):
# - In SS (**1000 vals**):
# - In SS (**1000 vals**):

# %% [markdown]
# - NOT in SS (**1000 vals**):
# - NOT in SS (**1000 vals**):
# - NOT in SS (**1000 vals**):

# %% [markdown]
# **In Secondary Stucture Avg:**
#
# **Not in Secondary Structure Avg:**

# %% [markdown]
# **Human Glucokinase**

# %% [markdown]
# - In SS (**500 vals**): Pearson r (p): (0.45536078562614063, 2.4153182166259887e-52)
# - In SS (**500 vals**):
# - In SS (**500 vals**):

# %% [markdown]
# - NOT in SS (**500 vals**): Pearson r (p): (0.4895249489327368, 2.1940834447497067e-61)
# - NOT in SS (**500 vals**):
# - NOT in SS (**500 vals**):

# %%
pr = round(mean([0.455, 0.489]), 3)
print(pr)
# Out:
# 0.472

# %% [markdown]
# ** to use only for plots
#
# **In Secondary Stucture Avg:** 0.455
#
# **Not in Secondary Structure Avg:** 0.489
#
# **Diff** -0.034

# %% [markdown]
# - In SS (**1000 vals**):
# - In SS (**1000 vals**):
# - In SS (**1000 vals**):

# %% [markdown]
# - NOT in SS (**1000 vals**):
# - NOT in SS (**1000 vals**):
# - NOT in SS (**1000 vals**):

# %% [markdown]
# **In Secondary Stucture Avg:**
#
# **Not in Secondary Structure Avg:**

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import sem

plt.rcParams["figure.figsize"] = [5.2, 5.2]
plt.rcParams["figure.autolayout"] = True


diff = np.array([0.014, 0.08, 0.174, 0.086, -0.032, -0.059, -0.09, -0.034])
sec_str = np.array([0.69, 0.54, 0.52, 0.64, 0.70, 0.61, 0.59, 0.69])
# n = ['Small ubiquitin-related modifier 1', 'Ube4b', 'Bgl3', 'avGFP', 'Pab1', 'GB1']

plt.title('Difference vs. Secondary Structure Fraction')
plt.xlabel("Sec Str Fraction", fontsize=13)
plt.xticks(fontsize=11)
# plt.xlim(left=0.4, right=0.75)
plt.ylabel("Difference", fontsize=13)
plt.yticks(fontsize=11)
# plt.ylim(top=0.75, bottom=0.25)

plt.scatter(sec_str, diff)

# plt.axis('square')
# plt.errorbar(sec_str, diff)

# plt.savefig('Pearson\'s R vs. Secondary Structure Fraction.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import sem

plt.rcParams["figure.figsize"] = [5.2, 5.2]
plt.rcParams["figure.autolayout"] = True


diff = np.array([0.014, 0.08, 0.174, 0.086, -0.032, -0.059, -0.09, -0.034])
pearsons_r = np.array([0.868, 0.316, 0.443, 0.734, 0.907, 0.550, 0.689, 0.472])
# n = ['Small ubiquitin-related modifier 1', 'Ube4b', 'Bgl3', 'avGFP', 'Pab1', 'GB1']

plt.title('Difference vs. Pearson\'s R')
plt.xlabel("pearson's R", fontsize=13)
plt.xticks(fontsize=11)
# plt.xlim(left=0.4, right=0.75)
plt.ylabel("Difference", fontsize=13)
plt.yticks(fontsize=11)
# plt.ylim(top=0.75, bottom=0.25)

plt.scatter(pearsons_r, diff)

# plt.axis('square')
# plt.errorbar(sec_str, diff)

# plt.savefig('Pearson\'s R vs. Secondary Structure Fraction.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import sem

plt.rcParams["figure.figsize"] = [5.2, 5.2]
plt.rcParams["figure.autolayout"] = True


pearsons_r = np.array([0.868, 0.316, 0.443, 0.734, 0.907, 0.550, 0.689, 0.472])
sec_str = np.array([0.69, 0.54, 0.52, 0.64, 0.70, 0.61, 0.59, 0.69])
# n = ['Small ubiquitin-related modifier 1', 'Ube4b', 'Bgl3', 'avGFP', 'Pab1', 'GB1']

plt.title('Avg Pearson\'s vs. Secondary Structure Fraction')
plt.xlabel("Sec Str Fraction", fontsize=13)
plt.xticks(fontsize=11)
# plt.xlim(left=0.4, right=0.75)
plt.ylabel("Pearson's R", fontsize=13)
plt.yticks(fontsize=11)
# plt.ylim(top=0.75, bottom=0.25)

plt.scatter(sec_str, pearsons_r)

# plt.axis('square')
# plt.errorbar(sec_str, diff)

# plt.savefig('Pearson\'s R vs. Secondary Structure Fraction.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Running Pt. 1 (initial values)

# %% [markdown]
# **Pab1**

# %% [markdown]
# - In SS (**500 train, 1000 test**): Pearson r (p): (0.8842890500456597, 0.0)
# - Not in SS (**500 train, 1000 test**): Pearson r (p): (0.8464597179826654, 2.0091466803908308e-275)

# %% [markdown]
# Orig Avgs:
# - In SS: 0.875
# - Not in SS: 0.861

# %% [markdown]
# **Bgl3**

# %% [markdown]
# - In SS (**500 train, 1000 test**): Pearson r (p): (0.43426730597607893, 2.9792486872863174e-47)
# - Not in SS (**500 train, 1000 test**): Pearson r (p): (0.2458204815447993, 3.1427441799573777e-15)

# %% [markdown]
# Orig Avgs:
# - In SS: 0.356
# - Not in SS: 0.276

# %% [markdown]
# **GB1**

# %% [markdown]
# - In SS (**500 train, 1000 test**): Pearson r (p): (0.9585690212488946, 0.0)
# - Not in SS (**500 train, 1000 test**): Pearson r (p): (0.9427111798471934, 0.0)

# %% [markdown]
# Orig Avgs:
# - In SS: 0.891
# - Not in SS: 0.923

# %% [markdown]
# **1nd4**

# %% [markdown]
# - In SS (**500 train, 300 test**): Pearson r (p): (0.6423290521294867, 2.6748842708867263e-36)
# - Not in SS (**500 train, 300 test**): Pearson r (p): (0.4658134042001754, 1.455990433791423e-17)

# %% [markdown]
# Orig Avgs:
# - In SS: 0.521
# - Not in SS: 0.580

# %% [markdown]
# **4bz3**

# %% [markdown]
# - In SS (**500 train, 200 test**): Pearson r (p): (0.8686116744513144, 2.6979717792447993e-62)
# - Not in SS (**500 train, 200 test**): Pearson r (p): (0.7439961109869292, 1.618711727577653e-36)

# %% [markdown]
# Orig Avgs:
# - In SS: 0.644
# - Not in SS: 0.734

# %% [markdown]
# **Modifier 1**

# %% [markdown]
# - In SS (**400 train, 100 test**): Pearson r (p): (0.6714503979112778, 2.0801357411514434e-14)
# - In SS (**400 train, 100 test**): Pearson r (p): (0.5945489790673684, 6.944685963290795e-11)
# - Not in SS (**400 train, 100 test**): Pearson r (p): (0.7518600154963662, 1.9834186892303821e-19)
# - Not in SS (**400 train, 100 test**): Pearson r (p): (0.7833453819156131, 5.912067263738506e-22)

# %% [markdown]
# Orig Avgs:
# - In SS:
# - Not in SS:

# %% [markdown]
# **Glucokinase**

# %% [markdown]
# - In SS (**500 train, 500 test**): Pearson r (p): (0.6344043652922484, 1.1567227985497598e-57)
# - In SS (**500 train, 500 test**): Pearson r (p): (0.5377925651559381, 7.985824390579615e-39)
# - Not in SS (**500 train, 500 test**): Pearson r (p): (0.6411466674951127, 3.097024667586833e-59)
# - Not in SS (**500 train, 500 test**): Pearson r (p): (0.5963469247580406, 1.781555456974871e-49)

# %% [markdown]
# Orig Avgs:
# - In SS: 0.455
# - Not in SS: 0.489

# %% [markdown]
# ## Running Pt. 1 w/ Turns (200 train, 100 test)

# %% [markdown]
# **Pab1**

# %% [markdown]
# - In SS: Pearson r (p): (0.8142663343565117, 6.399989405624253e-13)
# - In SS: Pearson r (p): (0.8281351868023636, 1.1742141816874343e-13)
# - In SS: Pearson r (p): (0.8226977317655664, 2.323032795630548e-13)
# - NOT in SS: Pearson r (p): (0.3283674105797326, 0.019904315217078007)
# - NOT in SS: Pearson r (p): (0.19543474728378102, 0.17378670765994347)
# - NOT in SS: Pearson r (p): (0.047886493471686206, 0.7412233129175351)

# %%
in_ss = round(mean([0.8142663343565117, 0.8281351868023636, 0.8226977317655664]), 3)
print("in ss: " + str(in_ss))
not_in_ss = round(mean([0.3283674105797326, 0.19543474728378102, 0.047886493471686206]), 3)
print("not in ss: " + str(not_in_ss))
# Out:
# in ss: 0.822
# not in ss: 0.191

# %% [markdown]
# **Bgl3**

# %% [markdown]
# - In SS: Pearson r (p): (0.27666929793483785, 0.051772739606977536)
# - In SS: Pearson r (p): (0.49158395424842516, 0.00028856472926563345)
# - In SS: Pearson r (p): (0.45817037019774753, 0.0008202081364041556)
# - NOT in SS: Pearson r (p): (0.2963205243679141, 0.03666383948094182)
# - NOT in SS: Pearson r (p): (0.13202698260465331, 0.3607332853515076)
# - NOT in SS: Pearson r (p): (0.34570691781060925, 0.01393128792356743)

# %%
in_ss = round(mean([0.27666929793483785, 0.49158395424842516, 0.45817037019774753]), 3)
print("in ss: " + str(in_ss))
not_in_ss = round(mean([0.2963205243679141, 0.13202698260465331, 0.34570691781060925]), 3)
print("not in ss: " + str(not_in_ss))
# Out:
# in ss: 0.409
# not in ss: 0.258

# %% [markdown]
# **Ube4b**

# %% [markdown]
# - In SS: Pearson r (p): (0.20349007446260026, 0.15637261271867553)
# - In SS: Pearson r (p): (0.4547876610313489, 0.0009064391444105465)
# - In SS: Pearson r (p): (0.4270823009482384, 0.001980172510219775)
# - NOT in SS: Pearson r (p): (0.41146085883061917, 0.0029916820687782945)
# - NOT in SS: Pearson r (p): (0.35541472989072465, 0.011312547447267639)
# - NOT in SS: Pearson r (p): (0.4382080839615741, 0.0014582165319569293)

# %%
in_ss = round(mean([0.20349007446260026, 0.4547876610313489, 0.4270823009482384]), 3)
print("in ss: " + str(in_ss))
not_in_ss = round(mean([0.41146085883061917, 0.35541472989072465, 0.4382080839615741]), 3)
print("not in ss: " + str(not_in_ss))
# Out:
# in ss: 0.362
# not in ss: 0.402

# %% [markdown]
# **avgfp**

# %% [markdown]
# - In SS: Pearson r (p): (0.7680951194332037, 7.505277955742547e-11)
# - In SS: Pearson r (p): (0.7774547755376855, 3.133790746059982e-11)
# - In SS: Pearson r (p): (0.7363018132465566, 1.1028536620071063e-09)
# - NOT in SS: Pearson r (p): (0.5337358704613804, 6.56542353341293e-05)
# - NOT in SS: Pearson r (p): (0.3897352837967165, 0.005146721093430242)
# - NOT in SS: Pearson r (p): (0.675817382062317, 7.241383894426003e-08)

# %%
in_ss = round(mean([0.7680951194332037, 0.7774547755376855, 0.7363018132465566]), 3)
print("in ss: " + str(in_ss))
not_in_ss = round(mean([0.5337358704613804, 0.3897352837967165, 0.675817382062317]), 3)
print("not in ss: " + str(not_in_ss))
# Out:
# in ss: 0.761
# not in ss: 0.533

# %% [markdown]
# **gb1**

# %% [markdown]
# - In SS: Pearson r (p): (0.9097938428174899, 5.856910364335654e-20)
# - In SS: Pearson r (p): (0.8901071397369107, 5.3248535270341065e-18)
# - In SS: Pearson r (p): (0.9049042393185749, 1.965064089932739e-19)
# - NOT in SS: Pearson r (p): (0.8983414186644352, 9.036561212902434e-19)
# - NOT in SS: Pearson r (p): (0.8733440191907905, 1.3214388438142791e-16)
# - NOT in SS: Pearson r (p): (0.8688485702782084, 2.8951245416600264e-16)

# %%
in_ss = round(mean([0.9097938428174899, 0.8901071397369107, 0.9049042393185749]), 3)
print("in ss: " + str(in_ss))
not_in_ss = round(mean([0.8983414186644352, 0.8733440191907905, 0.8688485702782084]), 3)
print("not in ss: " + str(not_in_ss))
# Out:
# in ss: 0.902
# not in ss: 0.88

# %% [markdown]
# **glucokinase**

# %% [markdown]
# - In SS: Pearson r (p): (0.5577915563302529, 2.5723886587429236e-05)
# - In SS: Pearson r (p): (0.3724990170682661, 0.00772250073310606)
# - In SS: Pearson r (p): (0.4138924553540817, 0.0028091249555925015)
# - NOT in SS: Pearson r (p): (0.5496913523639442, 3.5551524060976275e-05)
# - NOT in SS: Pearson r (p): (0.5765439447047679, 1.176394708685527e-05)
# - NOT in SS: Pearson r (p): (0.5414477146884418, 4.89985207987176e-05)

# %%
in_ss = round(mean([0.5577915563302529, 0.3724990170682661, 0.4138924553540817]), 3)
print("in ss: " + str(in_ss))
not_in_ss = round(mean([0.5496913523639442, 0.5765439447047679, 0.5414477146884418]), 3)
print("not in ss: " + str(not_in_ss))
# Out:
# in ss: 0.448
# not in ss: 0.556

# %% [markdown]
# **modifier 1**

# %% [markdown]
# - In SS: Pearson r (p): (0.6331925585909413, 8.031103468553147e-07)
# - In SS: Pearson r (p): (0.5233746961293082, 9.62083984508657e-05)
# - In SS: Pearson r (p): (0.5697260299159372, 1.5721554320885035e-05)
# - NOT in SS: Pearson r (p): (0.6469634543147718, 3.845142894000922e-07)
# - NOT in SS: Pearson r (p): (0.5911424328720778, 6.182724760859062e-06)
# - NOT in SS: Pearson r (p): (0.593563125208673, 5.540249326977714e-06)

# %%
in_ss = round(mean([0.6331925585909413, 0.5233746961293082, 0.5697260299159372]), 3)
print("in ss: " + str(in_ss))
not_in_ss = round(mean([0.6469634543147718, 0.5911424328720778, 0.593563125208673]), 3)
print("not in ss: " + str(not_in_ss))
# Out:
# in ss: 0.575
# not in ss: 0.611

# %% [markdown]
# **1nd4**

# %% [markdown]
# - In SS: Pearson r (p): (0.6968117342031669, 1.9031363457776706e-08)
# - In SS: Pearson r (p): (0.5884931760049862, 6.964496533024053e-06)
# - In SS: Pearson r (p): (0.6343783505726204, 7.54830334155185e-07)
# - NOT in SS: Pearson r (p): (0.4814902749491874, 0.0004001232118331574)
# - NOT in SS: Pearson r (p): (0.3897222103418885, 0.00514834704350607)
# - NOT in SS: Pearson r (p): (0.398606660318871, 0.004141734064430469)

# %%
in_ss = round(mean([0.6968117342031669, 0.5884931760049862, 0.6343783505726204]), 3)
print("in ss: " + str(in_ss))
not_in_ss = round(mean([0.4814902749491874, 0.3897222103418885, 0.398606660318871]), 3)
print("not in ss: " + str(not_in_ss))
# Out:
# in ss: 0.64
# not in ss: 0.423

# %% [markdown]
# **3dqw**

# %% [markdown]
# - In SS: Pearson r (p): (0.7215661469754889, 3.3775961109661145e-09)
# - In SS: Pearson r (p): (0.7021107907507741, 1.3339585763926507e-08)
# - In SS: Pearson r (p): (0.7320086476213641, 1.5395941699226791e-09)
# - NOT in SS: Pearson r (p): (0.6937019627188415, 2.3361989234953616e-08)
# - NOT in SS: Pearson r (p): (0.523642146978236, 9.527890530781979e-05)
# - NOT in SS: Pearson r (p): (0.43346055759861374, 0.001663680122668489)

# %%
in_ss = round(mean([0.7215661469754889, 0.7215661469754889, 0.7320086476213641]), 3)
print("in ss: " + str(in_ss))
not_in_ss = round(mean([0.6937019627188415, 0.523642146978236, 0.43346055759861374]), 3)
print("not in ss: " + str(not_in_ss))
# Out:
# in ss: 0.725
# not in ss: 0.55

# %% [markdown]
# **4bz3**

# %% [markdown]
# - In SS: Pearson r (p): (0.622116496172715, 1.4154770870417482e-06)
# - In SS: Pearson r (p): (0.8057138755144793, 1.7001041853035196e-12)
# - In SS: Pearson r (p): (0.7051501979808172, 1.0841918542668429e-08)
# - NOT in SS: Pearson r (p): (0.7566595111846678, 2.067930455355557e-10)
# - NOT in SS: Pearson r (p): (0.7756504603169116, 3.7204522610541136e-11)
# - NOT in SS: Pearson r (p): (0.7860184879619708, 1.3573601073809862e-11)

# %%
in_ss = round(mean([0.622116496172715, 0.8057138755144793, 0.7051501979808172]), 3)
print("in ss: " + str(in_ss))
not_in_ss = round(mean([0.7566595111846678, 0.7756504603169116, 0.7860184879619708]), 3)
print("not in ss: " + str(not_in_ss))
# Out:
# in ss: 0.711
# not in ss: 0.773

# %%
# 1000 training values, 1000 test values (same test set for each protein)

plt.rcParams["figure.figsize"] = [12, 12]
plt.rcParams["figure.autolayout"] = True

# data
pab1_trials_200_ss = [0.8142663343565117, 0.8281351868023636, 0.8226977317655664]
pab1_trials_200_not_ss = [0.3283674105797326, 0.19543474728378102, 0.047886493471686206]
bgl3_trials_200_ss = [0.27666929793483785, 0.49158395424842516, 0.45817037019774753]
bgl3_trials_200_not_ss = [0.2963205243679141, 0.13202698260465331, 0.34570691781060925]
ube4b_trials_200_ss = [0.20349007446260026, 0.4547876610313489, 0.4270823009482384]
ube4b_trials_200_not_ss = [0.41146085883061917, 0.35541472989072465, 0.4382080839615741]
avgfp_trials_200_ss = [0.7680951194332037, 0.7774547755376855, 0.7363018132465566]
avgfp_trials_200_not_ss = [0.5337358704613804, 0.3897352837967165, 0.675817382062317]
gb1_trials_200_ss = [0.9097938428174899, 0.8901071397369107, 0.9049042393185749]
gb1_trials_200_not_ss = [0.8983414186644352, 0.8733440191907905, 0.8688485702782084]
glucokinase_trials_200_ss = [0.5577915563302529, 0.3724990170682661, 0.4138924553540817]
glucokinase_trials_200_not_ss = [0.5496913523639442, 0.5765439447047679, 0.5414477146884418]
mod_1_trials_200_ss = [0.6331925585909413, 0.5233746961293082, 0.5697260299159372]
mod_1_trials_200_not_ss = [0.6469634543147718, 0.5911424328720778, 0.593563125208673]
pro_1nd4_trials_200_ss = [0.6968117342031669, 0.5884931760049862, 0.634378350572620]
pro_1nd4_trials_200_not_ss = [0.4814902749491874, 0.3897222103418885, 0.398606660318871]
pro_3dqw_trials_200_ss = [0.7215661469754889, 0.7021107907507741, 0.7320086476213641]
pro_3dqw_trials_200_not_ss = [0.6937019627188415, 0.523642146978236, 0.43346055759861374]
pro_4bz3_trials_200_ss = [0.622116496172715, 0.8057138755144793, 0.7051501979808172]
pro_4bz3_trials_200_not_ss = [0.7566595111846678, 0.7756504603169116, 0.7860184879619708]

# calculating sem
pab1_200_ss_sem = sem(pab1_trials_200_ss) 
pab1_200_not_ss_sem = sem(pab1_trials_200_not_ss)
bgl3_200_ss_sem = sem(bgl3_trials_200_ss)
bgl3_200_not_ss_sem = sem(bgl3_trials_200_not_ss)
ube4b_200_ss_sem = sem(ube4b_trials_200_ss)
ube4b_200_not_ss = sem(ube4b_trials_200_not_ss)
avgfp_200_ss_sem = sem(avgfp_trials_200_ss)
avgfp_200_not_ss = sem(avgfp_trials_200_not_ss)
gb1_200_ss_sem = sem(gb1_trials_200_not_ss)
gb1_200_not_ss = sem(ube4b_trials_200_not_ss)
glucokinase_200_ss_sem = sem(glucokinase_trials_200_ss)
glucokinase_200_not_ss = sem(glucokinase_trials_200_not_ss)
mod_1_200_ss_sem = sem(mod_1_trials_200_ss)
mod_1_200_not_ss = sem(mod_1_trials_200_not_ss)
pro_1nd4_200_ss_sem = sem(pro_1nd4_trials_200_ss)
pro_1nd4_200_not_ss = sem(pro_1nd4_trials_200_not_ss)
pro_3dqw_ss_sem = sem(pro_3dqw_trials_200_ss)
pro_3dqw_not_ss = sem(pro_3dqw_trials_200_not_ss)
pro_4bz3_ss_sem = sem(pro_4bz3_trials_200_ss)
pro_4bz3_not_ss = sem(pro_4bz3_trials_200_not_ss)

yerr_ss = [pab1_200_ss_sem, bgl3_200_ss_sem, ube4b_200_ss_sem, avgfp_200_ss_sem, gb1_200_ss_sem,
           glucokinase_200_ss_sem, mod_1_200_ss_sem, pro_1nd4_200_ss_sem, pro_3dqw_ss_sem, pro_4bz3_ss_sem]
yerr_not_ss = [pab1_200_not_ss_sem, bgl3_200_not_ss_sem, ube4b_200_not_ss, avgfp_200_not_ss, gb1_200_not_ss,
              glucokinase_200_not_ss, mod_1_200_not_ss, pro_1nd4_200_not_ss, pro_3dqw_not_ss, pro_4bz3_not_ss]


# average at the top
labels = ['Pab1', 'Bgl3', 'Ube4b', 'avGFP', 'GB1', 'Glucokinase', 'Modifier 1', '1nd4', '3dqw', '4bz3']
# avgs, not percentage
sec_str = [0.822, 0.409, 0.362, 0.761, 0.902, 0.448, 0.575, 0.64, 0.725, 0.711]
no_sec_str = [0.191, 0.258, 0.402, 0.533, 0.88, 0.556, 0.611, 0.423, 0.55, 0.773]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, sec_str, width, label='In Sec Str', yerr = yerr_ss)
rects2 = ax.bar(x + width/2, no_sec_str, width, label='Not in Sec Str', yerr = yerr_not_ss)
# rects1 = ax.bar(x - width/2, sec_str, width, label='In Sec Str')
# rects2 = ax.bar(x + width/2, no_sec_str, width, label='Not in Sec Str')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Pearson\'s R Correlation Coefficient', fontsize=15)
# ax.set_xlabel('Protein', fontsize=15)
ax.set_title('200 Training Values 100 Test', y=1.02, fontsize=15)
ax.set_xticks(x)
ax.set_xticklabels(labels, y=-0.01, fontdict={'fontsize':15})
ax.set_yticks(np.arange(0, 1.1, 0.1))
# ax.tick_params(axis='x', labelsize=8)
ax.legend()

ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

fig.tight_layout()

plt.savefig('1000 Train.png', bbox_inches='tight')
#plt.show()
# Out:
# C:\Users\deepti\AppData\Local\Temp\ipykernel_16376\1363256349.py:87: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig('1000 Train.png', bbox_inches='tight')

# %% [markdown]
# File Names Used:
# - pab1_MLformat_ss_500_train_1000_test_t1.txt
#     - pab1_last_loss_500_train.txt
#     - pab1_last_val_lost_500_train.txt
#     - pab1_pred_500_train.txt
#     - pab1_best_targets_500_train.txt
# - pab1_MLformat_ss_500_train_1000_test_t2.txt
#     - pab1_last_loss_500_train_t2.txt
#     - pab1_last_val_lost_500_train_t2.txt
#     - pab1_pred_500_train_t2.txt
#     - pab1_best_targets_500_train_t2.txt
# - pab1_MLformat_ss_500_train_1000_test_t3.txt
#     - pab1_last_loss_500_train_t3.txt
#     - pab1_last_val_lost_500_train_t3.txt
#     - pab1_pred_500_train_t3.txt
#     - pab1_best_targets_500_train_t3.txt
# - pab1_MLformat_not_ss_500_train_1000_test_t1.txt
#     - pab1_last_loss_500_train_t1.1.txt
#     - pab1_last_val_lost_500_train_t1.1.txt
#     - pab1_pred_500_train_t1.1.txt
#     - pab1_best_targets_500_train_t1.1.txt
# - pab1_MLformat_not_ss_500_train_1000_test_t2.txt
#     - pab1_last_loss_500_train_t2.1.txt
#     - pab1_last_val_lost_500_train_t2.1.txt
#     - pab1_pred_500_train_t2.1.txt
#     - pab1_best_targets_500_train_t2.1.txt
# - pab1_MLformat_not_ss_500_train_1000_test_t3.txt
#     - pab1_last_loss_500_train_t3.1.txt
#     - pab1_last_val_lost_500_train_t3.1.txt
#     - pab1_pred_500_train_t3.1.txt
#     - pab1_best_targets_500_train_t3.1.txt
# - pab1_MLformat_ss_1000_train_1000_test_t1.txt
#     - pab1_last_loss_1000_train.txt
#     - pab1_last_val_lost_1000_train.txt
#     - pab1_pred_1000_train.txt
#     - pab1_best_targets_1000_train.txt
# - pab1_MLformat_ss_1000_train_1000_test_t2.txt
#     - pab1_last_loss_1000_train_t2.txt
#     - pab1_last_val_lost_1000_train_t2.txt
#     - pab1_pred_1000_train_t2.txt
#     - pab1_best_targets_1000_train_t2.txt
# - pab1_MLformat_ss_1000_train_1000_test_t3.txt
#     - pab1_last_loss_1000_train_t3.txt
#     - pab1_last_val_lost_1000_train_t3.txt
#     - pab1_pred_1000_train_t3.txt
#     - pab1_best_targets_1000_train_t3.txt
# - pab1_MLformat_not_ss_1000_train_1000_test_t1.txt
#     - pab1_last_loss_1000_train_t1.1.txt
#     - pab1_last_val_lost_1000_train_t1.1.txt
#     - pab1_pred_1000_train_t1.1.txt
#     - pab1_best_targets_1000_train_t1.1.txt
# - pab1_MLformat_not_ss_1000_train_1000_test_t2.txt
#     - pab1_last_loss_1000_train_t2.1.txt
#     - pab1_last_val_lost_1000_train_t2.1.txt
#     - pab1_pred_1000_train_t2.1.txt
#     - pab1_best_targets_1000_train_t2.1.txt
# - pab1_MLformat_not_ss_1000_train_1000_test_t3.txt
#     - pab1_last_loss_1000_train_t3.1.txt
#     - pab1_last_val_lost_1000_train_t3.1.txt
#     - pab1_pred_1000_train_t3.1.txt
#     - pab1_best_targets_1000_train_t3.1.txt

# %% [markdown]
# - pab1_MLformat_ss_50_train_1000_test_t1.txt
#     - pab1_last_loss_50_train.txt
#     - pab1_last_val_lost_50_train.txt
#     - pab1_pred_50_train.txt
#     - pab1_best_targets_50_train.txt
# - pab1_MLformat_ss_50_train_1000_test_t2.txt
#     - pab1_last_loss_50_train_t2.txt
#     - pab1_last_val_lost_50_train_t2.txt
#     - pab1_pred_50_train_t2.txt
#     - pab1_best_targets_50_train_t2.txt
# - pab1_MLformat_ss_50_train_1000_test_t3.txt
#     - pab1_last_loss_50_train_t3.txt
#     - pab1_last_val_lost_50_train_t3.txt
#     - pab1_pred_50_train_t3.txt
#     - pab1_best_targets_50_train_t3.txt
# - pab1_MLformat_not_ss_50_train_1000_test_t1.txt
#     - pab1_last_loss_50_train_t1.1.txt
#     - pab1_last_val_lost_50_train_t1.1.txt
#     - pab1_pred_50_train_t1.1.txt
#     - pab1_best_targets_50_train_t1.1.txt
# - pab1_MLformat_not_ss_50_train_1000_test_t2.txt
#     - pab1_last_loss_50_train_t2.1.txt
#     - pab1_last_val_lost_50_train_t2.1.txt
#     - pab1_pred_50_train_t2.1.txt
#     - pab1_best_targets_50_train_t2.1.txt
# - pab1_MLformat_not_ss_50_train_1000_test_t3.txt
#     - pab1_last_loss_50_train_t3.1.txt
#     - pab1_last_val_lost_50_train_t3.1.txt
#     - pab1_pred_50_train_t3.1.txt
#     - pab1_best_targets_50_train_t3.1.txt

# %% [markdown]
# - pab1_MLformat_ss_2000_train_1000_test_t1.txt
#     - pab1_last_loss_2000_train.txt
#     - pab1_last_val_lost_2000_train.txt
#     - pab1_pred_2000_train.txt
#     - pab1_best_targets_2000_train.txt
# - pab1_MLformat_ss_2000_train_1000_test_t2.txt
#     - pab1_last_loss_2000_train_t2.txt
#     - pab1_last_val_lost_2000_train_t2.txt
#     - pab1_pred_2000_train_t2.txt
#     - pab1_best_targets_2000_train_t2.txt
# - pab1_MLformat_ss_2000_train_1000_test_t3.txt
#     - pab1_last_loss_2000_train_t3.txt
#     - pab1_last_val_lost_2000_train_t3.txt
#     - pab1_pred_2000_train_t3.txt
#     - pab1_best_targets_2000_train_t3.txt
# - pab1_MLformat_not_ss_2000_train_1000_test_t1.txt
#     - pab1_last_loss_2000_train_t1.1.txt
#     - pab1_last_val_lost_2000_train_t1.1.txt
#     - pab1_pred_2000_train_t1.1.txt
#     - pab1_best_targets_2000_train_t1.1.txt
# - pab1_MLformat_not_ss_2000_train_1000_test_t2.txt
#     - pab1_last_loss_2000_train_t2.1.txt
#     - pab1_last_val_lost_2000_train_t2.1.txt
#     - pab1_pred_2000_train_t2.1.txt
#     - pab1_best_targets_2000_train_t2.1.txt
# - pab1_MLformat_not_ss_2000_train_1000_test_t3.txt
#     - pab1_last_loss_2000_train_t3.1.txt
#     - pab1_last_val_lost_2000_train_t3.1.txt
#     - pab1_pred_2000_train_t3.1.txt
#     - pab1_best_targets_2000_train_t3.1.txt

# %% [markdown]
# - pab1_MLformat_ss_150_train_1000_test_t1.txt
#     - pab1_last_loss_150_train.txt
#     - pab1_last_val_lost_150_train.txt
#     - pab1_pred_150_train.txt
#     - pab1_best_targets_150_train.txt
# - pab1_MLformat_ss_150_train_1000_test_t2.txt
#     - pab1_last_loss_150_train_t2.txt
#     - pab1_last_val_lost_150_train_t2.txt
#     - pab1_pred_150_train_t2.txt
#     - pab1_best_targets_150_train_t2.txt
# - pab1_MLformat_ss_150_train_1000_test_t3.txt
#     - pab1_last_loss_150_train_t3.txt
#     - pab1_last_val_lost_150_train_t3.txt
#     - pab1_pred_150_train_t3.txt
#     - pab1_best_targets_150_train_t3.txt
# - pab1_MLformat_not_ss_150_train_1000_test_t1.txt
#     - pab1_last_loss_150_train_t1.1.txt
#     - pab1_last_val_lost_150_train_t1.1.txt
#     - pab1_pred_150_train_t1.1.txt
#     - pab1_best_targets_150_train_t1.1.txt
# - pab1_MLformat_not_ss_150_train_1000_test_t2.txt
#     - pab1_last_loss_150_train_t2.1.txt
#     - pab1_last_val_lost_150_train_t2.1.txt
#     - pab1_pred_150_train_t2.1.txt
#     - pab1_best_targets_150_train_t2.1.txt
# - pab1_MLformat_not_ss_150_train_1000_test_t3.txt
#     - pab1_last_loss_150_train_t3.1.txt
#     - pab1_last_val_lost_150_train_t3.1.txt
#     - pab1_pred_150_train_t3.1.txt
#     - pab1_best_targets_150_train_t3.1.txt

# %% [markdown]
# File Names Used:
# - bgl3_MLformat_ss_500_train_1000_test_t1.txt
#     - bgl3_last_loss_500_train.txt
#     - bgl3_last_val_lost_500_train.txt
#     - bgl3_pred_500_train.txt
#     - bgl3_best_targets_500_train.txt
# - bgl3_MLformat_ss_500_train_1000_test_t2.txt
#     - bgl3_last_loss_500_train_t2.txt
#     - bgl3_last_val_lost_500_train_t2.txt
#     - bgl3_pred_500_train_t2.txt
#     - bgl3_best_targets_500_train_t2.txt
# - bgl3_MLformat_ss_500_train_1000_test_t3.txt
#     - bgl3_last_loss_500_train_t3.txt
#     - bgl3_last_val_lost_500_train_t3.txt
#     - bgl3_pred_500_train_t3.txt
#     - bgl3_best_targets_500_train_t3.txt
# - bgl3_MLformat_not_ss_500_train_1000_test_t1.txt
#     - bgl3_last_loss_500_train_t1.1.txt
#     - bgl3_last_val_lost_500_train_t1.1.txt
#     - bgl3_pred_500_train_t1.1.txt
#     - bgl3_best_targets_500_train_t1.1.txt
# - bgl3_MLformat_not_ss_500_train_1000_test_t2.txt
#     - bgl3_last_loss_500_train_t2.1.txt
#     - bgl3_last_val_lost_500_train_t2.1.txt
#     - bgl3_pred_500_train_t2.1.txt
#     - bgl3_best_targets_500_train_t2.1.txt
# - bgl3_MLformat_not_ss_500_train_1000_test_t3.txt
#     - bgl3_last_loss_500_train_t3.1.txt
#     - bgl3_last_val_lost_500_train_t3.1.txt
#     - bgl3_pred_500_train_t3.1.txt
#     - bgl3_best_targets_500_train_t3.1.txt
# - bgl3_MLformat_ss_1000_train_1000_test_t1.txt
#     - bgl3_last_loss_1000_train.txt
#     - bgl3_last_val_lost_1000_train.txt
#     - bgl3_pred_1000_train.txt
#     - bgl3_best_targets_1000_train.txt
# - bgl3_MLformat_ss_1000_train_1000_test_t2.txt
#     - bgl3_last_loss_1000_train_t2.txt
#     - bgl3_last_val_lost_1000_train_t2.txt
#     - bgl3_pred_1000_train_t2.txt
#     - bgl3_best_targets_1000_train_t2.txt
# - bgl3_MLformat_ss_1000_train_1000_test_t3.txt
#     - bgl3_last_loss_1000_train_t3.txt
#     - bgl3_last_val_lost_1000_train_t3.txt
#     - bgl3_pred_1000_train_t3.txt
#     - bgl3_best_targets_1000_train_t3.txt
# - bgl3_MLformat_not_ss_1000_train_1000_test_t1.txt
#     - bgl3_last_loss_1000_train_t1.1.txt
#     - bgl3_last_val_lost_1000_train_t1.1.txt
#     - bgl3_pred_1000_train_t1.1.txt
#     - bgl3_best_targets_1000_train_t1.1.txt
# - bgl3_MLformat_not_ss_1000_train_1000_test_t2.txt
#     - bgl3_last_loss_1000_train_t2.1.txt
#     - bgl3_last_val_lost_1000_train_t2.1.txt
#     - bgl3_pred_1000_train_t2.1.txt
#     - bgl3_best_targets_1000_train_t2.1.txt
# - bgl3_MLformat_not_ss_1000_train_1000_test_t3.txt
#     - bgl3_last_loss_1000_train_t3.1.txt
#     - bgl3_last_val_lost_1000_train_t3.1.txt
#     - bgl3_pred_1000_train_t3.1.txt
#     - bgl3_best_targets_1000_train_t3.1.txt

# %% [markdown]
# - bgl3_MLformat_ss_2000_train_1000_test_t1.txt
#     - bgl3_last_loss_2000_train.txt
#     - bgl3_last_val_lost_2000_train.txt
#     - bgl3_pred_2000_train.txt
#     - bgl3_best_targets_2000_train.txt
# - bgl3_MLformat_ss_2000_train_1000_test_t2.txt
#     - bgl3_last_loss_2000_train_t2.txt
#     - bgl3_last_val_lost_2000_train_t2.txt
#     - bgl3_pred_2000_train_t2.txt
#     - bgl3_best_targets_2000_train_t2.txt
# - bgl3_MLformat_ss_2000_train_1000_test_t3.txt
#     - bgl3_last_loss_2000_train_t3.txt
#     - bgl3_last_val_lost_2000_train_t3.txt
#     - bgl3_pred_2000_train_t3.txt
#     - bgl3_best_targets_2000_train_t3.txt
# - bgl3_MLformat_not_ss_2000_train_1000_test_t1.txt
#     - bgl3_last_loss_2000_train_t1.1.txt
#     - bgl3_last_val_lost_2000_train_t1.1.txt
#     - bgl3_pred_2000_train_t1.1.txt
#     - bgl3_best_targets_2000_train_t1.1.txt
# - bgl3_MLformat_not_ss_2000_train_1000_test_t2.txt
#     - bgl3_last_loss_2000_train_t2.1.txt
#     - bgl3_last_val_lost_2000_train_t2.1.txt
#     - bgl3_pred_2000_train_t2.1.txt
#     - bgl3_best_targets_2000_train_t2.1.txt
# - bgl3_MLformat_not_ss_2000_train_1000_test_t3.txt
#     - bgl3_last_loss_2000_train_t3.1.txt
#     - bgl3_last_val_lost_2000_train_t3.1.txt
#     - bgl3_pred_2000_train_t3.1.txt
#     - bgl3_best_targets_2000_train_t3.1.txt

# %% [markdown]
# - bgl3_MLformat_ss_3000_train_1000_test_t1.txt
#     - bgl3_last_loss_3000_train.txt
#     - bgl3_last_val_lost_3000_train.txt
#     - bgl3_pred_3000_train.txt
#     - bgl3_best_targets_3000_train.txt
# - bgl3_MLformat_ss_3000_train_1000_test_t2.txt
#     - bgl3_last_loss_3000_train_t2.txt
#     - bgl3_last_val_lost_3000_train_t2.txt
#     - bgl3_pred_3000_train_t2.txt
#     - bgl3_best_targets_3000_train_t2.txt
# - bgl3_MLformat_ss_3000_train_1000_test_t3.txt
#     - bgl3_last_loss_3000_train_t3.txt
#     - bgl3_last_val_lost_3000_train_t3.txt
#     - bgl3_pred_3000_train_t3.txt
#     - bgl3_best_targets_3000_train_t3.txt
# - bgl3_MLformat_not_ss_3000_train_1000_test_t1.txt
#     - bgl3_last_loss_3000_train_t1.1.txt
#     - bgl3_last_val_lost_3000_train_t1.1.txt
#     - bgl3_pred_3000_train_t1.1.txt
#     - bgl3_best_targets_3000_train_t1.1.txt
# - bgl3_MLformat_not_ss_3000_train_1000_test_t2.txt
#     - bgl3_last_loss_3000_train_t2.1.txt
#     - bgl3_last_val_lost_3000_train_t2.1.txt
#     - bgl3_pred_3000_train_t2.1.txt
#     - bgl3_best_targets_3000_train_t2.1.txt
# - bgl3_MLformat_not_ss_3000_train_1000_test_t3.txt
#     - bgl3_last_loss_3000_train_t3.1.txt
#     - bgl3_last_val_lost_3000_train_t3.1.txt
#     - bgl3_pred_3000_train_t3.1.txt
#     - bgl3_best_targets_3000_train_t3.1.txt

# %% [markdown]
# File Names Used:
# - ube4b_MLformat_ss_500_train_1000_test_t1.txt
#     - ube4b_last_loss_500_train.txt
#     - ube4b_last_val_lost_500_train.txt
#     - ube4b_pred_500_train.txt
#     - ube4b_best_targets_500_train.txt
# - ube4b_MLformat_ss_500_train_1000_test_t2.txt
#     - ube4b_last_loss_500_train_t2.txt
#     - ube4b_last_val_lost_500_train_t2.txt
#     - ube4b_pred_500_train_t2.txt
#     - ube4b_best_targets_500_train_t2.txt
# - ube4b_MLformat_ss_500_train_1000_test_t3.txt
#     - ube4b_last_loss_500_train_t3.txt
#     - ube4b_last_val_lost_500_train_t3.txt
#     - ube4b_pred_500_train_t3.txt
#     - ube4b_best_targets_500_train_t3.txt
# - ube4b_MLformat_not_ss_500_train_1000_test_t1.txt
#     - ube4b_last_loss_500_train_t1.1.txt
#     - ube4b_last_val_lost_500_train_t1.1.txt
#     - ube4b_pred_500_train_t1.1.txt
#     - ube4b_best_targets_500_train_t1.1.txt
# - ube4b_MLformat_not_ss_500_train_1000_test_t2.txt
#     - ube4b_last_loss_500_train_t2.1.txt
#     - ube4b_last_val_lost_500_train_t2.1.txt
#     - ube4b_pred_500_train_t2.1.txt
#     - ube4b_best_targets_500_train_t2.1.txt
# - ube4b_MLformat_not_ss_500_train_1000_test_t3.txt
#     - ube4b_last_loss_500_train_t3.1.txt
#     - ube4b_last_val_lost_500_train_t3.1.txt
#     - ube4b_pred_500_train_t3.1.txt
#     - ube4b_best_targets_500_train_t3.1.txt
# - ube4b_MLformat_ss_1000_train_1000_test_t1.txt
#     - ube4b_last_loss_1000_train.txt
#     - ube4b_last_val_lost_1000_train.txt
#     - ube4b_pred_1000_train.txt
#     - ube4b_best_targets_1000_train.txt
# - ube4b_MLformat_ss_1000_train_1000_test_t2.txt
#     - ube4b_last_loss_1000_train_t2.txt
#     - ube4b_last_val_lost_1000_train_t2.txt
#     - ube4b_pred_1000_train_t2.txt
#     - ube4b_best_targets_1000_train_t2.txt
# - ube4b_MLformat_ss_1000_train_1000_test_t3.txt
#     - ube4b_last_loss_1000_train_t3.txt
#     - ube4b_last_val_lost_1000_train_t3.txt
#     - ube4b_pred_1000_train_t3.txt
#     - ube4b_best_targets_1000_train_t3.txt
# - ube4b_MLformat_not_ss_1000_train_1000_test_t1.txt
#     - ube4b_last_loss_1000_train_t1.1.txt
#     - ube4b_last_val_lost_1000_train_t1.1.txt
#     - ube4b_pred_1000_train_t1.1.txt
#     - ube4b_best_targets_1000_train_t1.1.txt
# - ube4b_MLformat_not_ss_1000_train_1000_test_t2.txt
#     - ube4b_last_loss_1000_train_t2.1.txt
#     - ube4b_last_val_lost_1000_train_t2.1.txt
#     - ube4b_pred_1000_train_t2.1.txt
#     - ube4b_best_targets_1000_train_t2.1.txt
# - ube4b_MLformat_not_ss_1000_train_1000_test_t3.txt
#     - ube4b_last_loss_1000_train_t3.1.txt
#     - ube4b_last_val_lost_1000_train_t3.1.txt
#     - ube4b_pred_1000_train_t3.1.txt
#     - ube4b_best_targets_1000_train_t3.1.txt

# %% [markdown]
# - ube4b_MLformat_ss_2000_train_1000_test_t1.txt
#     - ube4b_last_loss_2000_train.txt
#     - ube4b_last_val_lost_2000_train.txt
#     - ube4b_pred_2000_train.txt
#     - ube4b_best_targets_2000_train.txt
# - ube4b_MLformat_ss_2000_train_1000_test_t2.txt
#     - ube4b_last_loss_2000_train_t2.txt
#     - ube4b_last_val_lost_2000_train_t2.txt
#     - ube4b_pred_2000_train_t2.txt
#     - ube4b_best_targets_2000_train_t2.txt
# - ube4b_MLformat_ss_2000_train_1000_test_t3.txt
#     - ube4b_last_loss_2000_train_t3.txt
#     - ube4b_last_val_lost_2000_train_t3.txt
#     - ube4b_pred_2000_train_t3.txt
#     - ube4b_best_targets_2000_train_t3.txt
# - ube4b_MLformat_not_ss_2000_train_1000_test_t1.txt
#     - ube4b_last_loss_2000_train_t1.1.txt
#     - ube4b_last_val_lost_2000_train_t1.1.txt
#     - ube4b_pred_2000_train_t1.1.txt
#     - ube4b_best_targets_2000_train_t1.1.txt
# - ube4b_MLformat_not_ss_2000_train_1000_test_t2.txt
#     - ube4b_last_loss_2000_train_t2.1.txt
#     - ube4b_last_val_lost_2000_train_t2.1.txt
#     - ube4b_pred_2000_train_t2.1.txt
#     - ube4b_best_targets_2000_train_t2.1.txt
# - ube4b_MLformat_not_ss_2000_train_1000_test_t3.txt
#     - ube4b_last_loss_2000_train_t3.1.txt
#     - ube4b_last_val_lost_2000_train_t3.1.txt
#     - ube4b_pred_2000_train_t3.1.txt
#     - ube4b_best_targets_2000_train_t3.1.txt

# %% [markdown]
# - ube4b_MLformat_ss_3000_train_1000_test_t1.txt
#     - ube4b_last_loss_3000_train.txt
#     - ube4b_last_val_lost_3000_train.txt
#     - ube4b_pred_3000_train.txt
#     - ube4b_best_targets_3000_train.txt
# - ube4b_MLformat_ss_3000_train_1000_test_t2.txt
#     - ube4b_last_loss_3000_train_t2.txt
#     - ube4b_last_val_lost_3000_train_t2.txt
#     - ube4b_pred_3000_train_t2.txt
#     - ube4b_best_targets_3000_train_t2.txt
# - ube4b_MLformat_ss_3000_train_1000_test_t3.txt
#     - ube4b_last_loss_3000_train_t3.txt
#     - ube4b_last_val_lost_3000_train_t3.txt
#     - ube4b_pred_3000_train_t3.txt
#     - ube4b_best_targets_3000_train_t3.txt
# - ube4b_MLformat_not_ss_3000_train_1000_test_t1.txt
#     - ube4b_last_loss_3000_train_t1.1.txt
#     - ube4b_last_val_lost_3000_train_t1.1.txt
#     - ube4b_pred_3000_train_t1.1.txt
#     - ube4b_best_targets_3000_train_t1.1.txt
# - ube4b_MLformat_not_ss_3000_train_1000_test_t2.txt
#     - ube4b_last_loss_3000_train_t2.1.txt
#     - ube4b_last_val_lost_3000_train_t2.1.txt
#     - ube4b_pred_3000_train_t2.1.txt
#     - ube4b_best_targets_3000_train_t2.1.txt
# - ube4b_MLformat_not_ss_3000_train_1000_test_t3.txt
#     - ube4b_last_loss_3000_train_t3.1.txt
#     - ube4b_last_val_lost_3000_train_t3.1.txt
#     - ube4b_pred_3000_train_t3.1.txt
#     - ube4b_best_targets_3000_train_t3.1.txt

# %% [markdown]
# File Names Used:
# - avGFP_MLformat_ss_500_train_1000_test_t1.txt
#     - avGFP_last_loss_500_train.txt
#     - avGFP_last_val_lost_500_train.txt
#     - avGFP_pred_500_train.txt
#     - avGFP_best_targets_500_train.txt
# - avGFP_MLformat_ss_500_train_1000_test_t2.txt
#     - avGFP_last_loss_500_train_t2.txt
#     - avGFP_last_val_lost_500_train_t2.txt
#     - avGFP_pred_500_train_t2.txt
#     - avGFP_best_targets_500_train_t2.txt
# - avGFP_MLformat_ss_500_train_1000_test_t3.txt
#     - avGFP_last_loss_500_train_t3.txt
#     - avGFP_last_val_lost_500_train_t3.txt
#     - avGFP_pred_500_train_t3.txt
#     - avGFP_best_targets_500_train_t3.txt
# - avGFP_MLformat_not_ss_500_train_1000_test_t1.txt
#     - avGFP_last_loss_500_train_t1.1.txt
#     - avGFP_last_val_lost_500_train_t1.1.txt
#     - avGFP_pred_500_train_t1.1.txt
#     - avGFP_best_targets_500_train_t1.1.txt
# - avGFP_MLformat_not_ss_500_train_1000_test_t2.txt
#     - avGFP_last_loss_500_train_t2.1.txt
#     - avGFP_last_val_lost_500_train_t2.1.txt
#     - avGFP_pred_500_train_t2.1.txt
#     - avGFP_best_targets_500_train_t2.1.txt
# - avGFP_MLformat_not_ss_500_train_1000_test_t3.txt
#     - avGFP_last_loss_500_train_t3.1.txt
#     - avGFP_last_val_lost_500_train_t3.1.txt
#     - avGFP_pred_500_train_t3.1.txt
#     - avGFP_best_targets_500_train_t3.1.txt
# - avGFP_MLformat_ss_1000_train_1000_test_t1.txt
#     - avGFP_last_loss_1000_train.txt
#     - avGFP_last_val_lost_1000_train.txt
#     - avGFP_pred_1000_train.txt
#     - avGFP_best_targets_1000_train.txt
# - avGFP_MLformat_ss_1000_train_1000_test_t2.txt
#     - avGFP_last_loss_1000_train_t2.txt
#     - avGFP_last_val_lost_1000_train_t2.txt
#     - avGFP_pred_1000_train_t2.txt
#     - avGFP_best_targets_1000_train_t2.txt
# - avGFP_MLformat_ss_1000_train_1000_test_t3.txt
#     - avGFP_last_loss_1000_train_t3.txt
#     - avGFP_last_val_lost_1000_train_t3.txt
#     - avGFP_pred_1000_train_t3.txt
#     - avGFP_best_targets_1000_train_t3.txt
# - avGFP_MLformat_not_ss_1000_train_1000_test_t1.txt
#     - avGFP_last_loss_1000_train_t1.1.txt
#     - avGFP_last_val_lost_1000_train_t1.1.txt
#     - avGFP_pred_1000_train_t1.1.txt
#     - avGFP_best_targets_1000_train_t1.1.txt
# - avGFP_MLformat_not_ss_1000_train_1000_test_t2.txt
#     - avGFP_last_loss_1000_train_t2.1.txt
#     - avGFP_last_val_lost_1000_train_t2.1.txt
#     - avGFP_pred_1000_train_t2.1.txt
#     - avGFP_best_targets_1000_train_t2.1.txt
# - avGFP_MLformat_not_ss_1000_train_1000_test_t3.txt
#     - avGFP_last_loss_1000_train_t3.1.txt
#     - avGFP_last_val_lost_1000_train_t3.1.txt
#     - avGFP_pred_1000_train_t3.1.txt
#     - avGFP_best_targets_1000_train_t3.1.txt

# %% [markdown]
# File Names Used:
# - gb1_MLformat_ss_500_train_1000_test_t1.txt
#     - gb1_last_loss_500_train.txt
#     - gb1_last_val_lost_500_train.txt
#     - gb1_pred_500_train.txt
#     - gb1_best_targets_500_train.txt
# - gb1_MLformat_ss_500_train_1000_test_t2.txt
#     - gb1_last_loss_500_train_t2.txt
#     - gb1_last_val_lost_500_train_t2.txt
#     - gb1_pred_500_train_t2.txt
#     - gb1_best_targets_500_train_t2.txt
# - gb1_MLformat_ss_500_train_1000_test_t3.txt
#     - gb1_last_loss_500_train_t3.txt
#     - gb1_last_val_lost_500_train_t3.txt
#     - gb1_pred_500_train_t3.txt
#     - gb1_best_targets_500_train_t3.txt
# - gb1_MLformat_not_ss_500_train_1000_test_t1.txt
#     - gb1_last_loss_500_train_t1.1.txt
#     - gb1_last_val_lost_500_train_t1.1.txt
#     - gb1_pred_500_train_t1.1.txt
#     - gb1_best_targets_500_train_t1.1.txt
# - gb1_MLformat_not_ss_500_train_1000_test_t2.txt
#     - gb1_last_loss_500_train_t2.1.txt
#     - gb1_last_val_lost_500_train_t2.1.txt
#     - gb1_pred_500_train_t2.1.txt
#     - gb1_best_targets_500_train_t2.1.txt
# - gb1_MLformat_not_ss_500_train_1000_test_t3.txt
#     - gb1_last_loss_500_train_t3.1.txt
#     - gb1_last_val_lost_500_train_t3.1.txt
#     - gb1_pred_500_train_t3.1.txt
#     - gb1_best_targets_500_train_t3.1.txt
# - gb1_MLformat_ss_1000_train_1000_test_t1.txt
#     - gb1_last_loss_1000_train.txt
#     - gb1_last_val_lost_1000_train.txt
#     - gb1_pred_1000_train.txt
#     - gb1_best_targets_1000_train.txt
# - gb1_MLformat_ss_1000_train_1000_test_t2.txt
#     - gb1_last_loss_1000_train_t2.txt
#     - gb1_last_val_lost_1000_train_t2.txt
#     - gb1_pred_1000_train_t2.txt
#     - gb1_best_targets_1000_train_t2.txt
# - gb1_MLformat_ss_1000_train_1000_test_t3.txt
#     - gb1_last_loss_1000_train_t3.txt
#     - gb1_last_val_lost_1000_train_t3.txt
#     - gb1_pred_1000_train_t3.txt
#     - gb1_best_targets_1000_train_t3.txt
# - gb1_MLformat_not_ss_1000_train_1000_test_t1.txt
#     - gb1_last_loss_1000_train_t1.1.txt
#     - gb1_last_val_lost_1000_train_t1.1.txt
#     - gb1_pred_1000_train_t1.1.txt
#     - gb1_best_targets_1000_train_t1.1.txt
# - gb1_MLformat_not_ss_1000_train_1000_test_t2.txt
#     - gb1_last_loss_1000_train_t2.1.txt
#     - gb1_last_val_lost_1000_train_t2.1.txt
#     - gb1_pred_1000_train_t2.1.txt
#     - gb1_best_targets_1000_train_t2.1.txt
# - gb1_MLformat_not_ss_1000_train_1000_test_t3.txt
#     - gb1_last_loss_1000_train_t3.1.txt
#     - gb1_last_val_lost_1000_train_t3.1.txt
#     - gb1_pred_1000_train_t3.1.txt
#     - gb1_best_targets_1000_train_t3.1.txt
# - gb1_MLformat_ss_2000_train_1000_test_t1.txt
#     - gb1_last_loss_2000_train.txt
#     - gb1_last_val_lost_2000_train.txt
#     - gb1_pred_2000_train.txt
#     - gb1_best_targets_2000_train.txt
# - gb1_MLformat_ss_2000_train_1000_test_t2.txt
#     - gb1_last_loss_2000_train_t2.txt
#     - gb1_last_val_lost_2000_train_t2.txt
#     - gb1_pred_2000_train_t2.txt
#     - gb1_best_targets_2000_train_t2.txt
# - gb1_MLformat_ss_2000_train_1000_test_t3.txt
#     - gb1_last_loss_2000_train_t3.txt
#     - gb1_last_val_lost_2000_train_t3.txt
#     - gb1_pred_2000_train_t3.txt
#     - gb1_best_targets_2000_train_t3.txt
# - gb1_MLformat_not_ss_2000_train_1000_test_t1.txt
#     - gb1_last_loss_2000_train_t1.1.txt
#     - gb1_last_val_lost_2000_train_t1.1.txt
#     - gb1_pred_2000_train_t1.1.txt
#     - gb1_best_targets_2000_train_t1.1.txt
# - gb1_MLformat_not_ss_2000_train_1000_test_t2.txt
#     - gb1_last_loss_2000_train_t2.1.txt
#     - gb1_last_val_lost_2000_train_t2.1.txt
#     - gb1_pred_2000_train_t2.1.txt
#     - gb1_best_targets_2000_train_t2.1.txt
# - gb1_MLformat_not_ss_2000_train_1000_test_t3.txt
#     - gb1_last_loss_2000_train_t3.1.txt
#     - gb1_last_val_lost_2000_train_t3.1.txt
#     - gb1_pred_2000_train_t3.1.txt
#     - gb1_best_targets_2000_train_t3.1.txt

# %% [markdown]
# - pro_ind4_MLformat_ss_500_train_1000_test_t1.txt
#     - pro_ind4_last_loss_500_train.txt
#     - pro_ind4_last_val_lost_500_train.txt
#     - pro_ind4_pred_500_train.txt
#     - pro_ind4_best_targets_500_train.txt
# - pro_ind4_MLformat_ss_500_train_1000_test_t2.txt
#     - pro_ind4_last_loss_500_train_t2.txt
#     - pro_ind4_last_val_lost_500_train_t2.txt
#     - pro_ind4_pred_500_train_t2.txt
#     - pro_ind4_best_targets_500_train_t2.txt
# - pro_ind4_MLformat_ss_500_train_1000_test_t3.txt
#     - pro_ind4_last_loss_500_train_t3.txt
#     - pro_ind4_last_val_lost_500_train_t3.txt
#     - pro_ind4_pred_500_train_t3.txt
#     - pro_ind4_best_targets_500_train_t3.txt
# - pro_ind4_MLformat_not_ss_500_train_1000_test_t1.txt
#     - pro_ind4_last_loss_500_train_t1.1.txt
#     - pro_ind4_last_val_lost_500_train_t1.1.txt
#     - pro_ind4_pred_500_train_t1.1.txt
#     - pro_ind4_best_targets_500_train_t1.1.txt
# - pro_ind4_MLformat_not_ss_500_train_1000_test_t2.txt
#     - pro_ind4_last_loss_500_train_t2.1.txt
#     - pro_ind4_last_val_lost_500_train_t2.1.txt
#     - pro_ind4_pred_500_train_t2.1.txt
#     - pro_ind4_best_targets_500_train_t2.1.txt
# - pro_ind4_MLformat_not_ss_500_train_1000_test_t3.txt
#     - pro_ind4_last_loss_500_train_t3.1.txt
#     - pro_ind4_last_val_lost_500_train_t3.1.txt
#     - pro_ind4_pred_500_train_t3.1.txt
#     - pro_ind4_best_targets_500_train_t3.1.txt

# %% [markdown]
# - pro_4bz3_MLformat_ss_500_train_1000_test_t1.txt
#     - pro_4bz3_last_loss_500_train.txt
#     - pro_4bz3_last_val_lost_500_train.txt
#     - pro_4bz3_pred_500_train.txt
#     - pro_4bz3_best_targets_500_train.txt
# - pro_4bz3_MLformat_ss_500_train_1000_test_t2.txt
#     - pro_4bz3_last_loss_500_train_t2.txt
#     - pro_4bz3_last_val_lost_500_train_t2.txt
#     - pro_4bz3_pred_500_train_t2.txt
#     - pro_4bz3_best_targets_500_train_t2.txt
# - pro_4bz3_MLformat_ss_500_train_1000_test_t3.txt
#     - pro_4bz3_last_loss_500_train_t3.txt
#     - pro_4bz3_last_val_lost_500_train_t3.txt
#     - pro_4bz3_pred_500_train_t3.txt
#     - pro_4bz3_best_targets_500_train_t3.txt
# - pro_4bz3_MLformat_not_ss_500_train_1000_test_t1.txt
#     - pro_4bz3_last_loss_500_train_t1.1.txt
#     - pro_4bz3_last_val_lost_500_train_t1.1.txt
#     - pro_4bz3_pred_500_train_t1.1.txt
#     - pro_4bz3_best_targets_500_train_t1.1.txt
# - pro_4bz3_MLformat_not_ss_500_train_1000_test_t2.txt
#     - pro_4bz3_last_loss_500_train_t2.1.txt
#     - pro_4bz3_last_val_lost_500_train_t2.1.txt
#     - pro_4bz3_pred_500_train_t2.1.txt
#     - pro_4bz3_best_targets_500_train_t2.1.txt
# - pro_4bz3_MLformat_not_ss_500_train_1000_test_t3.txt
#     - pro_4bz3_last_loss_500_train_t3.1.txt
#     - pro_4bz3_last_val_lost_500_train_t3.1.txt
#     - pro_4bz3_pred_500_train_t3.1.txt
#     - pro_4bz3_best_targets_500_train_t3.1.txt

# %% [markdown]
# - pro_3dqw_MLformat_ss_500_train_1000_test_t1.txt
#     - pro_3dqw_last_loss_500_train.txt
#     - pro_3dqw_last_val_lost_500_train.txt
#     - pro_3dqw_pred_500_train.txt
#     - pro_3dqw_best_targets_500_train.txt
# - pro_3dqw_MLformat_ss_500_train_1000_test_t2.txt
#     - pro_3dqw_last_loss_500_train_t2.txt
#     - pro_3dqw_last_val_lost_500_train_t2.txt
#     - pro_3dqw_pred_500_train_t2.txt
#     - pro_3dqw_best_targets_500_train_t2.txt
# - pro_3dqw_MLformat_ss_500_train_1000_test_t3.txt
#     - pro_3dqw_last_loss_500_train_t3.txt
#     - pro_3dqw_last_val_lost_500_train_t3.txt
#     - pro_3dqw_pred_500_train_t3.txt
#     - pro_3dqw_best_targets_500_train_t3.txt
# - pro_3dqw_MLformat_not_ss_500_train_1000_test_t1.txt
#     - pro_3dqw_last_loss_500_train_t1.1.txt
#     - pro_3dqw_last_val_lost_500_train_t1.1.txt
#     - pro_3dqw_pred_500_train_t1.1.txt
#     - pro_3dqw_best_targets_500_train_t1.1.txt
# - pro_3dqw_MLformat_not_ss_500_train_1000_test_t2.txt
#     - pro_3dqw_last_loss_500_train_t2.1.txt
#     - pro_3dqw_last_val_lost_500_train_t2.1.txt
#     - pro_3dqw_pred_500_train_t2.1.txt
#     - pro_3dqw_best_targets_500_train_t2.1.txt
# - pro_3dqw_MLformat_not_ss_500_train_1000_test_t3.txt
#     - pro_3dqw_last_loss_500_train_t3.1.txt
#     - pro_3dqw_last_val_lost_500_train_t3.1.txt
#     - pro_3dqw_pred_500_train_t3.1.txt
#     - pro_3dqw_best_targets_500_train_t3.1.txt
# - pro_3dqw_MLformat_ss_1000_train_1000_test_t1.txt
#     - pro_3dqw_last_loss_1000_train.txt
#     - pro_3dqw_last_val_lost_1000_train.txt
#     - pro_3dqw_pred_1000_train.txt
#     - pro_3dqw_best_targets_1000_train.txt
# - pro_3dqw_MLformat_ss_1000_train_1000_test_t2.txt
#     - pro_3dqw_last_loss_1000_train_t2.txt
#     - pro_3dqw_last_val_lost_1000_train_t2.txt
#     - pro_3dqw_pred_1000_train_t2.txt
#     - pro_3dqw_best_targets_1000_train_t2.txt
# - pro_3dqw_MLformat_ss_1000_train_1000_test_t3.txt
#     - pro_3dqw_last_loss_1000_train_t3.txt
#     - pro_3dqw_last_val_lost_1000_train_t3.txt
#     - pro_3dqw_pred_1000_train_t3.txt
#     - pro_3dqw_best_targets_1000_train_t3.txt
# - pro_3dqw_MLformat_not_ss_1000_train_1000_test_t1.txt
#     - pro_3dqw_last_loss_1000_train_t1.1.txt
#     - pro_3dqw_last_val_lost_1000_train_t1.1.txt
#     - pro_3dqw_pred_1000_train_t1.1.txt
#     - pro_3dqw_best_targets_1000_train_t1.1.txt
# - pro_3dqw_MLformat_not_ss_1000_train_1000_test_t2.txt
#     - pro_3dqw_last_loss_1000_train_t2.1.txt
#     - pro_3dqw_last_val_lost_1000_train_t2.1.txt
#     - pro_3dqw_pred_1000_train_t2.1.txt
#     - pro_3dqw_best_targets_1000_train_t2.1.txt
# - pro_3dqw_MLformat_not_ss_1000_train_1000_test_t3.txt
#     - pro_3dqw_last_loss_1000_train_t3.1.txt
#     - pro_3dqw_last_val_lost_1000_train_t3.1.txt
#     - pro_3dqw_pred_1000_train_t3.1.txt
#     - pro_3dqw_best_targets_1000_train_t3.1.txt

# %% [markdown]
# - glucokinase_MLformat_ss_500_train_1000_test_t1.txt
#     - glucokinase_last_loss_500_train.txt
#     - glucokinase_last_val_lost_500_train.txt
#     - glucokinase_pred_500_train.txt
#     - glucokinase_best_targets_500_train.txt
# - glucokinase_MLformat_ss_500_train_1000_test_t2.txt
#     - glucokinase_last_loss_500_train_t2.txt
#     - glucokinase_last_val_lost_500_train_t2.txt
#     - glucokinase_pred_500_train_t2.txt
#     - glucokinase_best_targets_500_train_t2.txt
# - glucokinase_MLformat_ss_500_train_1000_test_t3.txt
#     - glucokinase_last_loss_500_train_t3.txt
#     - glucokinase_last_val_lost_500_train_t3.txt
#     - glucokinase_pred_500_train_t3.txt
#     - glucokinase_best_targets_500_train_t3.txt
# - glucokinase_MLformat_not_ss_500_train_1000_test_t1.txt
#     - glucokinase_last_loss_500_train_t1.1.txt
#     - glucokinase_last_val_lost_500_train_t1.1.txt
#     - glucokinase_pred_500_train_t1.1.txt
#     - glucokinase_best_targets_500_train_t1.1.txt
# - glucokinase_MLformat_not_ss_500_train_1000_test_t2.txt
#     - glucokinase_last_loss_500_train_t2.1.txt
#     - glucokinase_last_val_lost_500_train_t2.1.txt
#     - glucokinase_pred_500_train_t2.1.txt
#     - glucokinase_best_targets_500_train_t2.1.txt
# - glucokinase_MLformat_not_ss_500_train_1000_test_t3.txt
#     - glucokinase_last_loss_500_train_t3.1.txt
#     - glucokinase_last_val_lost_500_train_t3.1.txt
#     - glucokinase_pred_500_train_t3.1.txt
#     - glucokinase_best_targets_500_train_t3.1.txt
# - glucokinase_MLformat_ss_1000_train_1000_test_t1.txt
#     - glucokinase_last_loss_1000_train.txt
#     - glucokinase_last_val_lost_1000_train.txt
#     - glucokinase_pred_1000_train.txt
#     - glucokinase_best_targets_1000_train.txt
# - glucokinase_MLformat_ss_1000_train_1000_test_t2.txt
#     - glucokinase_last_loss_1000_train_t2.txt
#     - glucokinase_last_val_lost_1000_train_t2.txt
#     - glucokinase_pred_1000_train_t2.txt
#     - glucokinase_best_targets_1000_train_t2.txt
# - glucokinase_MLformat_ss_1000_train_1000_test_t3.txt
#     - glucokinase_last_loss_1000_train_t3.txt
#     - glucokinase_last_val_lost_1000_train_t3.txt
#     - glucokinase_pred_1000_train_t3.txt
#     - glucokinase_best_targets_1000_train_t3.txt
# - glucokinase_MLformat_not_ss_1000_train_1000_test_t1.txt
#     - glucokinase_last_loss_1000_train_t1.1.txt
#     - glucokinase_last_val_lost_1000_train_t1.1.txt
#     - glucokinase_pred_1000_train_t1.1.txt
#     - glucokinase_best_targets_1000_train_t1.1.txt
# - glucokinase_MLformat_not_ss_1000_train_1000_test_t2.txt
#     - glucokinase_last_loss_1000_train_t2.1.txt
#     - glucokinase_last_val_lost_1000_train_t2.1.txt
#     - glucokinase_pred_1000_train_t2.1.txt
#     - glucokinase_best_targets_1000_train_t2.1.txt
# - glucokinase_MLformat_not_ss_1000_train_1000_test_t3.txt
#     - glucokinase_last_loss_1000_train_t3.1.txt
#     - glucokinase_last_val_lost_1000_train_t3.1.txt
#     - glucokinase_pred_1000_train_t3.1.txt
#     - glucokinase_best_targets_1000_train_t3.1.txt

# %% [markdown]
# ## Running Tests on all Proteins

# %% [markdown]
# **GB1**

# %% [markdown]
# - Pab1 Architecture (**960** vals): Pearson r (p): (**0.787288143897696**, 9.187075780321463e-42)

# %% [markdown]
# - Bgl3 Architecture (**960** vals): Pearson r (p): (**0.8291472924965031**, 7.162085973668165e-50)

# %% [markdown]
# - Ube4b Architecture (**960** vals): Pearson r (p): (**0.8104505302111167**, 5.314578384653344e-46)

# %% [markdown]
# - Pab1 Architecture (**480** vals): Pearson r (p): (0.7043324355001468, 1.1824610335142155e-15)

# %% [markdown]
# - Bgl3 Architecture (**480** vals): Pearson r (p): (0.7657111003627706, 1.0246451189465408e-19)

# %% [markdown]
# - Ube4b Architecture (**480** vals): Pearson r (p): (0.7545115593370085, 6.918280973903179e-19)

# %% [markdown]
# - Pab1 Architecture (**160** vals): Pearson r (p): (0.5987159980648021, 0.00029455991839733405)

# %% [markdown]
# - Bgl3 Architecture 32 batch (**40** vals): Pearson r (p): (**0.5404695086578368**, 0.16666985197592005)

# %% [markdown]
# **avGFP**

# %% [markdown]
# - Bgl3 Architecture 32 batch (**465** vals): Pearson r (p): (0.7102890884062991, 0.0)

# %% [markdown]
# **Immunoglobulin G-binding protein G**

# %% [markdown]
# - Bgl3 Architecture 32 batch (**160** vals):

# %% [markdown]
# **Endolysin**

# %% [markdown]
# **Thermonuclease**

# %% [markdown]
# **Ube4b**

# %% [markdown]
#  - Bgl3 Architecture 32 batch (**80** vals): Pearson r (p): (**0.42823552431100953**, 0.09795565144938942)

# %% [markdown]
# **Bgl3**

# %% [markdown]
#  - Bgl3 Architecture 32 batch (**360** vals): Pearson r (p): (**0.33121101881157294**, 0.004484281710952349)

# %% [markdown]
# **Pab1**

# %% [markdown]
# - Bgl3 Architecture 32 batch (**40** vals): Pearson r (p): (**0.51999627290939**, 0.18650606880206608)

# %% [markdown]
# ## Scaling w/ Ube4b Architecture and all test values

# %% [markdown]
# **Ube4b Scaling Runs** - Testing values for scaling (10k test values)

# %% [markdown]
# - Bgl3 Architecture 64 train vals: Pearson r (p): (**0.27630090957902637**, 1.1222328934115771e-174)

# %% [markdown]
# - Bgl3 Architecture 80 train vals: Pearson r (p): (0.20525680242299663, 1.3786058505176699e-95)

# %% [markdown]
# - Bgl3 Architecture 100 train vals: Pearson r (p): (0.28970028627530875, 1.3483414572324957e-192)

# %% [markdown]
# - Bgl3 Architecture 150 train vals: Pearson r (p): (0.3182732530901569, 3.342278891190891e-234)

# %% [markdown]
# - **Bgl3 Architecture 200 train vals: Pearson r (p): (0.35897544561994443, 6.885015672993327e-302)**
# - Pearson r (p): (0.3645689474720337, 5.265484394583e-312) new fixed val

# %% [markdown]
# - Bgl3 Architecture 250 train vals: Pearson r (p): (0.37327463857991167, 0.0)

# %% [markdown]
# - Bgl3 Architecture 300 train vals: Pearson r (p): (0.3707361683228152, 2e-323)

# %% [markdown]
# - Bgl3 Architecture 350 train vals: Pearson r (p): (0.3742049292942585, 0.0)

# %% [markdown]
# - Bgl3 Architecture 700 train vals: Pearson r (p): (0.40791336082450785, 0.0)

# %% [markdown]
# - Bgl3 Architecture 2000 train vals: Pearson r (p): (0.5435576563882909, 0.0)

# %% [markdown]
# ## Runs

# %% [markdown]
# **Ube4b**

# %% [markdown]
# - **Bgl3 Architecture 200 train vals:** Pearson r (p): (0.31752947397065395, 1.25796555389e-312)
# - **Bgl3 Architecture 200 train vals:** Pearson r (p): (0.33465549978288195, 0.0)
# - **Bgl3 Architecture 200 train vals:** Pearson r (p): (0.31247570072920106, 2.658850207652331e-302)

# %% [markdown]
# **avGFP**

# %% [markdown]
# - **Bgl3 Architecture 465 train vals:** Pearson r (p): (0.710083012700699, 0.0)
# - **Bgl3 Architecture 465 train vals:** Pearson r (p): (0.7030185125891608, 0.0)
# - **Bgl3 Architecture 465 train vals:** Pearson r (p): (0.7049796913441765, 0.0)

# %% [markdown]
# **GB1**

# %% [markdown]
# - **Bgl3 Architecture 110 train vals:** Pearson r (p): (0.6194761800282778, 0.0)
# - **Bgl3 Architecture 110 train vals:** Pearson r (p): (0.5790423887438166, 0.0)
# - **Bgl3 Architecture 110 train vals:** Pearson r (p): (0.627454382323644, 0.0)

# %% [markdown]
# **Pab1**

# %% [markdown]
# - **Bgl3 Architecture 147 train vals:** Pearson r (p): (0.5417644951977244, 0.0)
# - **Bgl3 Architecture 147 train vals:** Pearson r (p): (0.5705441360531436, 0.0)
# - **Bgl3 Architecture 147 train vals:** Pearson r (p): (0.5719824172003054, 0.0)

# %% [markdown]
# **Small ubiquitin-related modifier 1**

# %% [markdown]
# - **Bgl3 Architecture 198 train vals (part 1):** Pearson r (p): (0.3150657241023825, 1.7319145146724647e-40)
# - **Bgl3 Architecture 198 train vals (part 1):** Pearson r (p): (0.3848698055205211, 3.884664563117792e-61)
# - **Bgl3 Architecture 198 train vals (part 1):** Pearson r (p): (0.3734951589525354, 2.0755752218792584e-57)

# %% [markdown]
# **Bgl3**

# %% [markdown]
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.33958805421917987, 0.0)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.33163222599674475, 0.0)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.33868567141551764, 0.0)

# %% [markdown]
# **Thermonuclease**

# %% [markdown]
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.5168868453284623, 2.605248017947444e-43)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.4723914402300202, 1.6558438735630858e-35)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.44131083319181436, 1.064921060774665e-30)

# %% [markdown]
# **Human glucokinase**

# %% [markdown]
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.434193369925872, 0.0)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.44427832753329966, 0.0)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.4133940136702442, 4.514886350166e-312)

# %% [markdown]
# **1be9**

# %% [markdown]
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.5246842052625195, 4.766995848332641e-94)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.5740525522139392, 2.6576655360018355e-116)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.47915661779818897, 1.5138391828275788e-76)

# %% [markdown]
# **1nd4**

# %% [markdown]
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.5220994432451006, 3.4256392766990557e-277)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.5035515705619638, 7.003197278827369e-255)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.5203731258378809, 4.678390410024972e-275)

# %% [markdown]
# **3dqw**

# %% [markdown]
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.6446227648997263, 7.196006248546517e-128)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.6432630849279763, 3.616597458284155e-127)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.6429607465544099, 5.172926685218491e-127)

# %% [markdown]
# **4bz3**

# %% [markdown]
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.6669548113322177, 0.0)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.6548398903425647, 0.0)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.633360251054482, 0.0)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import sem

plt.rcParams["figure.figsize"] = [5.2, 5.2]
plt.rcParams["figure.autolayout"] = True

# calculating error
ube4b_trials = [0.31752947397065395, 0.33465549978288195, 0.31247570072920106]
avgfp_trials = [0.710083012700699, 0.7030185125891608, 0.7049796913441765]
gb1_trials = [0.6194761800282778, 0.5790423887438166, 0.627454382323644]
pab1_trials = [0.5417644951977244, 0.5705441360531436, 0.5719824172003054]
mod_1_trials = [0.3150657241023825, 0.3848698055205211, 0.3734951589525354]
bgl3_trials = [0.33958805421917987, 0.33163222599674475, 0.33868567141551764]
glucokinase_trials = [0.434193369925872, 0.44427832753329966, 0.4133940136702442]
pro_1be9_trials = [0.5246842052625195, 0.5740525522139392, 0.47915661779818897]
pro_3dqw_trials = [0.6446227648997263, 0.6432630849279763, 0.6429607465544099]
pro_4bz3_trials = [0.6669548113322177, 0.6548398903425647, 0.633360251054482]
nuclease_trials = [0.5168868453284623, 0.4723914402300202, 0.4413108331918143]
pro_1nd4_trials = [0.5220994432451006, 0.5035515705619638, 0.5203731258378809]

# calculating the standard error of mean
ube4b_error = sem(ube4b_trials)
avgfp_error = sem(avgfp_trials)
gb1_error = sem(gb1_trials)
pab1_error = sem(pab1_trials) 
mod_1_error = sem(mod_1_trials)
bgl3_error = sem(bgl3_trials)
glucokinase_error = sem(glucokinase_trials)
pro_1be9_error = sem(pro_1be9_trials)
pro_3dqw_error = sem(pro_3dqw_trials)
pro_4bz3_error = sem(pro_4bz3_trials)
nuclease_error = sem(nuclease_trials)
pro_1nd4_error = sem(pro_1nd4_trials)

yerror = [mod_1_error, ube4b_error, bgl3_error, avgfp_error, pab1_error, gb1_error, glucokinase_error, pro_1be9_error,
          pro_3dqw_error, pro_4bz3_error, nuclease_error, pro_1nd4_error]

sec_str = np.array([0.46, 0.52, 0.54, 0.64, 0.69, 0.70, 0.69, 0.55, 0.60, 0.59, 0.62, 0.61])
pearson_r = np.array([0.30, 0.32, 0.34, 0.71, 0.54, 0.62, 0.43, 0.53, 0.643, 0.651, 0.48, 0.52])
# n = ['Small ubiquitin-related modifier 1', 'Ube4b', 'Bgl3', 'avGFP', 'Pab1', 'GB1']

plt.title('Pearson\'s R vs. Secondary Structure Fraction')
plt.xlabel("Sec Str Fraction", fontsize=13)
plt.xticks(fontsize=11)
plt.xlim(left=0.4, right=0.75)
plt.ylabel("Pearson's R", fontsize=13)
plt.yticks(fontsize=11)
plt.ylim(top=0.75, bottom=0.25)

plt.scatter(sec_str, pearson_r)

plt.text(x=pearson_r[0]+0.17, y=sec_str[0]-0.18, s='Small ubiquitin-related modifier 1')
plt.text(x=pearson_r[1]+0.21, y=sec_str[1]-0.21, s='Ube4b')
plt.text(x=pearson_r[2]+0.21, y=sec_str[2]-0.205, s='Bgl3')
plt.text(x=pearson_r[3]-0.06, y=sec_str[3]+0.065, s='avGFP')
plt.text(x=pearson_r[4]+0.17, y=sec_str[4]-0.075, s='Pab1')
plt.text(x=pearson_r[5]+0.08, y=sec_str[5]-0.165, s='GB1')
plt.text(x=pearson_r[6]+0.18, y=sec_str[6]-0.26, s='glucokinase')
plt.text(x=pearson_r[7]+0.030, y=sec_str[7]-0.025, s='1be9')
plt.text(x=pearson_r[8]-0.032, y=sec_str[8]+0.038, s='3dqw')
plt.text(x=pearson_r[9]-0.052, y=sec_str[9]+0.068, s='4bz3')
plt.text(x=pearson_r[10]+0.15, y=sec_str[10]-0.15, s='Thermonuclease')
plt.text(x=pearson_r[11]+0.1, y=sec_str[11]-0.095, s='1nd4')

# plt.axis('square')
plt.errorbar(sec_str, pearson_r, yerr=yerror, fmt='o', ecolor='orange', barsabove=True)

plt.savefig('Pearson\'s R vs. Secondary Structure Fraction.png', bbox_inches='tight')
plt.show()
# Out:
# C:\Users\deepti\AppData\Local\Temp\ipykernel_16376\3564561046.py:69: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig('Pearson\'s R vs. Secondary Structure Fraction.png', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import sem

plt.rcParams["figure.figsize"] = [5.2, 5.2]
plt.rcParams["figure.autolayout"] = True

# calculating error
ube4b_trials = [0.31752947397065395, 0.33465549978288195, 0.31247570072920106]
avgfp_trials = [0.710083012700699, 0.7030185125891608, 0.7049796913441765]
gb1_trials = [0.6194761800282778, 0.5790423887438166, 0.627454382323644]
pab1_trials = [0.5417644951977244, 0.5705441360531436, 0.5719824172003054]
mod_1_trials = [0.3150657241023825, 0.3848698055205211, 0.3734951589525354]
bgl3_trials = [0.33958805421917987, 0.33163222599674475, 0.33868567141551764]
glucokinase_trials = [0.434193369925872, 0.44427832753329966, 0.4133940136702442]
pro_1be9_trials = [0.5246842052625195, 0.5740525522139392, 0.47915661779818897]
pro_3dqw_trials = [0.6446227648997263, 0.6432630849279763, 0.6429607465544099]
pro_4bz3_trials = [0.6669548113322177, 0.6548398903425647, 0.633360251054482]
nuclease_trials = [0.5168868453284623, 0.4723914402300202, 0.4413108331918143]
pro_1nd4_trials = [0.5220994432451006, 0.5035515705619638, 0.5203731258378809]

# calculating the standard error of mean
ube4b_error = sem(ube4b_trials)
avgfp_error = sem(avgfp_trials)
gb1_error = sem(gb1_trials)
pab1_error = sem(pab1_trials) 
mod_1_error = sem(mod_1_trials)
bgl3_error = sem(bgl3_trials)
glucokinase_error = sem(glucokinase_trials)
pro_1be9_error = sem(pro_1be9_trials)
pro_3dqw_error = sem(pro_3dqw_trials)
pro_4bz3_error = sem(pro_4bz3_trials)
nuclease_error = sem(nuclease_trials)
pro_1nd4_error = sem(pro_1nd4_trials)

yerror = [mod_1_error, ube4b_error, bgl3_error, avgfp_error, pab1_error, gb1_error, glucokinase_error, pro_1be9_error,
          pro_3dqw_error, pro_4bz3_error, nuclease_error, pro_1nd4_error]

sec_str = np.array([0.46, 0.52, 0.54, 0.64, 0.69, 0.70, 0.69, 0.55, 0.60, 0.59, 0.62, 0.61])
pearson_r = np.array([0.30, 0.32, 0.34, 0.71, 0.54, 0.62, 0.43, 0.53, 0.643, 0.651, 0.48, 0.52])
# n = ['Small ubiquitin-related modifier 1', 'Ube4b', 'Bgl3', 'avGFP', 'Pab1', 'GB1']

plt.title('Pearson\'s R vs. Secondary Structure Fraction')
plt.xlabel("Sec Str Fraction", fontsize=13)
plt.xticks(fontsize=11)
plt.xlim(left=0, right=1.0)
plt.ylabel("Pearson's R", fontsize=13)
plt.yticks(fontsize=11)
plt.ylim(top=1.0, bottom=0)

plt.scatter(sec_str, pearson_r)

plt.text(x=pearson_r[0]+0.17, y=sec_str[0]-0.18, s='Small ubiquitin-related modifier 1')
plt.text(x=pearson_r[1]+0.21, y=sec_str[1]-0.21, s='Ube4b')
plt.text(x=pearson_r[2]+0.21, y=sec_str[2]-0.205, s='Bgl3')
plt.text(x=pearson_r[3]-0.06, y=sec_str[3]+0.065, s='avGFP')
plt.text(x=pearson_r[4]+0.17, y=sec_str[4]-0.075, s='Pab1')
plt.text(x=pearson_r[5]+0.08, y=sec_str[5]-0.165, s='GB1')
plt.text(x=pearson_r[6]+0.18, y=sec_str[6]-0.26, s='glucokinase')
plt.text(x=pearson_r[7]+0.030, y=sec_str[7]-0.025, s='1be9')
plt.text(x=pearson_r[8]-0.032, y=sec_str[8]+0.038, s='3dqw')
plt.text(x=pearson_r[9]-0.052, y=sec_str[9]+0.068, s='4bz3')
plt.text(x=pearson_r[10]+0.15, y=sec_str[10]-0.15, s='Thermonuclease')
plt.text(x=pearson_r[11]+0.1, y=sec_str[11]-0.095, s='1nd4')

# plt.axis('square')
plt.errorbar(sec_str, pearson_r, yerr=yerror, fmt='o', ecolor='orange', barsabove=True)

plt.savefig('Pearson\'s R vs. Secondary Structure Fraction.png', bbox_inches='tight')
plt.show()
# Out:
# C:\Users\deepti\AppData\Local\Temp\ipykernel_16376\1491650601.py:69: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig('Pearson\'s R vs. Secondary Structure Fraction.png', bbox_inches='tight')

# %% [markdown]
# ## Pt 2 Runs Including Turns

# %% [markdown]
# **Ube4b**

# %% [markdown]
# - **Bgl3 Architecture 200 train vals:** Pearson r (p): (0.32985329165219346, 0.0)
# - **Bgl3 Architecture 200 train vals:** Pearson r (p): (0.34369073946391904, 0.0)
# - **Bgl3 Architecture 200 train vals:** Pearson r (p): (0.32397407245801846, 0.0)

# %%
in_ss = round(mean([0.32985329165219346, 0.34369073946391904, 0.32397407245801846]), 3)
print("avg: " + str(in_ss))
# Out:
# avg: 0.333

# %% [markdown]
# **avGFP**

# %% [markdown]
# - **Bgl3 Architecture 465 train vals:** Pearson r (p): (0.7270088608220108, 0.0)
# - **Bgl3 Architecture 465 train vals:** Pearson r (p): (0.7221645336972624, 0.0)
# - **Bgl3 Architecture 465 train vals:** Pearson r (p): (0.6981839211580043, 0.0)

# %%
in_ss = round(mean([0.7270088608220108, 0.7221645336972624, 0.6981839211580043]), 3)
print("avg: " + str(in_ss))
# Out:
# avg: 0.716

# %% [markdown]
# **GB1**

# %% [markdown]
# - **Bgl3 Architecture 110 train vals:** Pearson r (p): (0.577462893551693, 0.0)
# - **Bgl3 Architecture 110 train vals:** Pearson r (p): (0.5939019966620652, 0.0)
# - **Bgl3 Architecture 110 train vals:** Pearson r (p): (0.6006904646332852, 0.0)

# %%
in_ss = round(mean([0.577462893551693, 0.5939019966620652, 0.6006904646332852]), 3)
print("avg: " + str(in_ss))
# Out:
# avg: 0.591

# %% [markdown]
# **Pab1**

# %% [markdown]
# - **Bgl3 Architecture 147 train vals:**
# - **Bgl3 Architecture 147 train vals:**
# - **Bgl3 Architecture 147 train vals:**

# %% [markdown]
# **Small ubiquitin-related modifier 1** (Fix code to exclude alphafold values)

# %% [markdown]
# - **Bgl3 Architecture 198 train vals (part 1):**
# - **Bgl3 Architecture 198 train vals (part 1):**
# - **Bgl3 Architecture 198 train vals (part 1):**

# %% [markdown]
# **Bgl3**

# %% [markdown]
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.3199234202320816, 0.0)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.35174496788314447, 0.0)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.3622337169062419, 0.0)

# %%
in_ss = round(mean([0.3199234202320816, 0.35174496788314447, 0.3622337169062419]), 3)
print("avg: " + str(in_ss))
# Out:
# avg: 0.345

# %% [markdown]
# **Thermonuclease** (Fix code to exclude alphafold values)

# %% [markdown]
# - **Bgl3 Architecture 982 train vals:**
# - **Bgl3 Architecture 982 train vals:**
# - **Bgl3 Architecture 982 train vals:**

# %% [markdown]
# **Human glucokinase** (Fix code to exclude alphafold values)

# %% [markdown]
# - **Bgl3 Architecture 982 train vals:**
# - **Bgl3 Architecture 982 train vals:**
# - **Bgl3 Architecture 982 train vals:**

# %% [markdown]
# **1be9**

# %% [markdown]
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.5281944879406991, 7.045829108835924e-67)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.5464637532126224, 2.2902830625377603e-72)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.5859538614094009, 1.854402274786801e-85)

# %%
in_ss = round(mean([0.5281944879406991, 0.5464637532126224, 0.5859538614094009]), 3)
print("avg: " + str(in_ss))
# Out:
# avg: 0.554

# %% [markdown]
# **1nd4**

# %% [markdown]
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.4851847697385875, 1.6389871461501426e-213)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.511064889377582, 1.5766146374819032e-240)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.477266218725006, 1.06370910370932e-205)

# %%
in_ss = round(mean([0.4851847697385875, 0.511064889377582, 0.477266218725006]), 3)
print("avg: " + str(in_ss))
# Out:
# avg: 0.491

# %% [markdown]
# **3dqw**

# %% [markdown]
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.6393434386912622, 5.7500013452055567e-126)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.6398772656817217, 3.069207012140014e-126)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.6155652004757388, 2.3798286304145723e-114)

# %%
in_ss = round(mean([0.6393434386912622, 0.6398772656817217, 0.6155652004757388]), 3)
print("avg: " + str(in_ss))
# Out:
# avg: 0.632

# %% [markdown]
# **4bz3**

# %% [markdown]
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.6638940778272346, 0.0)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.6876937819206467, 0.0)
# - **Bgl3 Architecture 982 train vals:** Pearson r (p): (0.6676429966918197, 0.0)

# %%
in_ss = round(mean([0.6638940778272346, 0.6876937819206467, 0.6676429966918197]), 3)
print("avg: " + str(in_ss))
# Out:
# avg: 0.673

# %%
pearson_r = np.array([0.333, 0.716, 0.591, 0.345, 0.554, 0.491, 0.632, 0.673])
sec_str = np.array([0.91, 0.88, 0.91, 0.54, 0.81, 0.81, 0.64, 0.82])
# n = ['Small ubiquitin-related modifier 1', 'Ube4b', 'Bgl3', 'avGFP', 'Pab1', 'GB1']

plt.title('Pearson\'s R vs. Sec. Structure Fraction w/ Turns')
plt.xlabel("Sec Str Fraction", fontsize=13)
plt.xticks(fontsize=11)
plt.xlim(left=0, right=1.0)
plt.ylabel("Pearson's R", fontsize=13)
plt.yticks(fontsize=11)
plt.ylim(top=1.0, bottom=0)

plt.scatter(sec_str, pearson_r)

# %%
pearson_r = np.array([0.333, 0.716, 0.591, 0.345, 0.554, 0.491, 0.632, 0.673])
sec_str = np.array([0.91, 0.88, 0.91, 0.54, 0.81, 0.81, 0.64, 0.82])
# n = ['Small ubiquitin-related modifier 1', 'Ube4b', 'Bgl3', 'avGFP', 'Pab1', 'GB1']

plt.title('Pearson\'s R vs. Sec. Structure Fraction w/ Turns')
plt.xlabel("Sec Str Fraction", fontsize=13)
plt.xticks(fontsize=11)
plt.xlim(left=0.4, right=1.0)
plt.ylabel("Pearson's R", fontsize=13)
plt.yticks(fontsize=11)
plt.ylim(top=0.8, bottom=0.2)

plt.scatter(sec_str, pearson_r)

# %% [markdown]
# Files Used pt. 2:

# %% [markdown]
# - avgfp_MLformat_465_train_15150_test_t1.txt
#     - avgfp_last_loss_pt2.1.txt
#     - avgfp_last_val_lost_pt2.1.txt
#     - avgfp_pred_pt2.1.txt
#     - avgfp_best_targets_pt2.1.txt
# - avgfp_MLformat_465_train_15150_test_t2.txt
#     - avgfp_last_loss_pt2.2.txt
#     - avgfp_last_val_lost_pt2.2.txt
#     - avgfp_pred_pt2.2.txt
#     - avgfp_best_targets_pt2.2.txt
# - avgfp_MLformat_465_train_15150_test_t3.txt
#     - avgfp_last_loss_pt2.3.txt
#     - avgfp_last_val_lost_pt2.3.txt
#     - avgfp_pred_pt2.3.txt
#     - avgfp_best_targets_pt2.3.txt

# %% [markdown]
# - bgl3_MLformat_982_train_16723_test_t1.txt
#     - bgl3_last_loss_pt2.1.txt
#     - bgl3_last_val_lost_pt2.1.txt
#     - bgl3_pred_pt2.1.txt
#     - bgl3_best_targets_pt2.1.txt
# - bgl3_MLformat_982_train_16723_test_t2.txt
#     - bgl3_last_loss_pt2.2.txt
#     - bgl3_last_val_lost_pt2.2.txt
#     - bgl3_pred_pt2.2.txt
#     - bgl3_best_targets_pt2.2.txt
# - bgl3_MLformat_982_train_16723_test_t3.txt
#     - bgl3_last_loss_pt2.3.txt
#     - bgl3_last_val_lost_pt2.3.txt
#     - bgl3_pred_pt2.3.txt
#     - bgl3_best_targets_pt2.3.txt

# %% [markdown]
# - gb1_MLformat_110_train_14524_test_t1.txt
#     - bgl3_last_loss_pt2.1.txt
#     - bgl3_last_val_lost_pt2.1.txt
#     - bgl3_pred_pt2.1.txt
#     - bgl3_best_targets_pt2.1.txt
# - gb1_MLformat_110_train_14524_test_t2.txt
#     - bgl3_last_loss_pt2.2.txt
#     - bgl3_last_val_lost_pt2.2.txt
#     - bgl3_pred_pt2.2.txt
#     - bgl3_best_targets_pt2.2.txt
# - gb1_MLformat_110_train_14524_test_t3.txt
#     - bgl3_last_loss_pt2.3.txt
#     - bgl3_last_val_lost_pt2.3.txt
#     - bgl3_pred_pt2.3.txt
#     - bgl3_best_targets_pt2.3.txt

# %% [markdown]
# - pab1_MLformat_200_train_14344_test_t1.txt
#     - pab1_last_loss_pt2.1.txt
#     - pab1_last_val_lost_pt2.1.txt
#     - pab1_pred_pt2.1.txt
#     - pab1_best_targets_pt2.1.txt
# - pab1_MLformat_200_train_14344_test_t2.txt
#     - pab1_last_loss_pt2.2.txt
#     - pab1_last_val_lost_pt2.2.txt
#     - pab1_pred_pt2.2.txt
#     - pab1_best_targets_pt2.2.txt
# - pab1_MLformat_200_train_14344_test_t3.txt
#     - pab1_last_loss_pt2.3.txt
#     - pab1_last_val_lost_pt2.3.txt
#     - pab1_pred_pt2.3.txt
#     - pab1_best_targets_pt2.3.txt

# %% [markdown]
# - pro_1be9_MLformat_235_train_915_test_t1.txt
#     - pro_1be9_last_loss_pt2.1.txt
#     - pro_1be9_last_val_lost_pt2.1.txt
#     - pro_1be9_pred_pt2.1.txt
#     - pro_1be9_best_targets_pt2.1.txt
# - pro_1be9_MLformat_235_train_915_test_t2.txt
#     - pro_1be9_last_loss_pt2.2.txt
#     - pro_1be9_last_val_lost_pt2.2.txt
#     - pro_1be9_pred_pt2.2.txt
#     - pro_1be9_best_targets_pt2.2.txt
# - pro_1be9_MLformat_235_train_915_test_t3.txt
#     - pro_1be9_last_loss_pt2.3.txt
#     - pro_1be9_last_val_lost_pt2.3.txt
#     - pro_1be9_pred_pt2.3.txt
#     - pro_1be9_best_targets_pt2.3.txt

# %% [markdown]
# - pro_1nd4_MLformat_1000_train_3626_test_t1.txt
#     - pro_1nd4_last_loss_pt2.1.txt
#     - pro_1nd4_last_val_lost_pt2.1.txt
#     - pro_1nd4_pred_pt2.1.txt
#     - pro_1nd4_best_targets_pt2.1.txt
# - pro_1nd4_MLformat_1000_train_3626_test_t2.txt
#     - pro_1nd4_last_loss_pt2.2.txt
#     - pro_1nd4_last_val_lost_pt2.2.txt
#     - pro_1nd4_pred_pt2.2.txt
#     - pro_1nd4_best_targets_pt2.2.txt
# - pro_1nd4_MLformat_1000_train_3626_test_t3.txt
#     - pro_1nd4_last_loss_pt2.3.txt
#     - pro_1nd4_last_val_lost_pt2.3.txt
#     - pro_1nd4_pred_pt2.3.txt
#     - pro_1nd4_best_targets_pt2.3.txt

# %% [markdown]
# - pro_3dqw_MLformat_2170_train_1087_test_t1.txt
#     - pro_3dqw_last_loss_pt2.1.txt
#     - pro_3dqw_last_val_lost_pt2.1.txt
#     - pro_3dqw_pred_pt2.1.txt
#     - pro_3dqw_best_targets_pt2.1.txt
# - pro_3dqw_MLformat_2170_train_1087_test_t2.txt
#     - pro_3dqw_last_loss_pt2.2.txt
#     - pro_3dqw_last_val_lost_pt2.2.txt
#     - pro_3dqw_pred_pt2.2.txt
#     - pro_3dqw_best_targets_pt2.2.txt
# - pro_3dqw_MLformat_2170_train_1087_test_t3.txt
#     - pro_3dqw_last_loss_pt2.3.txt
#     - pro_3dqw_last_val_lost_pt2.3.txt
#     - pro_3dqw_pred_pt2.3.txt
#     - pro_3dqw_best_targets_pt2.3.txt

# %% [markdown]
# - pro_4bz3_MLformat_908_train_3588_test_t1.txt
#     - pro_4bz3_last_loss_pt2.1.txt
#     - pro_4bz3_last_val_lost_pt2.1.txt
#     - pro_4bz3_pred_pt2.1.txt
#     - pro_4bz3_best_targets_pt2.1.txt
# - pro_4bz3_MLformat_908_train_3588_test_t2.txt
#     - pro_4bz3_last_loss_pt2.2.txt
#     - pro_4bz3_last_val_lost_pt2.2.txt
#     - pro_4bz3_pred_pt2.2.txt
#     - pro_4bz3_best_targets_pt2.2.txt
# - pro_4bz3_MLformat_908_train_3588_test_t3.txt
#     - pro_4bz3_last_loss_pt2.3.txt
#     - pro_4bz3_last_val_lost_pt2.3.txt
#     - pro_4bz3_pred_pt2.3.txt
#     - pro_4bz3_best_targets_pt2.3.txt

# %% [markdown]
# - ube4b_MLformat_200_train_17155_test_t1.txt
#     - ube4b_last_loss_pt2.1.txt
#     - ube4b_last_val_lost_pt2.1.txt
#     - ube4b_pred_pt2.1.txt
#     - ube4b_best_targets_pt2.1.txt
# - ube4b_MLformat_200_train_17155_test_t2.txt
#     - ube4b_last_loss_pt2.2.txt
#     - ube4b_last_val_lost_pt2.2.txt
#     - ube4b_pred_pt2.2.txt
#     - ube4b_best_targets_pt2.2.txt
# - ube4b_MLformat_200_train_17155_test_t3.txt
#     - ube4b_last_loss_pt2.3.txt
#     - ube4b_last_val_lost_pt2.3.txt
#     - ube4b_pred_pt2.3.txt
#     - ube4b_best_targets_pt2.3.txt

# %% [markdown]
# Files Used:

# %% [markdown]
# - bgl3_MLformat_982_train_13945_test_t1
#     - bgl3_last_loss_982_train.txt
#     - bgl3_last_val_lost_982_train.txt
#     - bgl3_pred_982_train.txt
#     - bgl3_best_targets_982_train.txt
# - bgl3_MLformat_982_train_13945_test_t2
#     - bgl3_last_loss_982_train_t2.txt
#     - bgl3_last_val_lost_982_train_t2.txt
#     - bgl3_pred_982_train_t2.txt
#     - bgl3_best_targets_982_train_t2.txt
# - bgl3_MLformat_982_train_13945_test_t3
#     - bgl3_last_loss_982_train_t3.txt
#     - bgl3_last_val_lost_982_train_t3.txt
#     - bgl3_pred_982_train_t3.txt
#     - bgl3_best_targets_982_train_t3.txt
# - pab1_MLformat_147_train_25974_test_t1
#     - pab1_last_loss_147_train.txt
#     - pab1_last_val_lost_147_train.txt
#     - pab1_pred_147_train.txt
#     - pab1_best_targets_147_train.txt
# - pab1_MLformat_147_train_25974_test_t2
#     - pab1_last_loss_147_train_t2.txt
#     - pab1_last_val_lost_147_train_t2.txt
#     - pab1_pred_147_train_t2.txt
#     - pab1_best_targets_147_train_t2.txt
# - pab1_MLformat_147_train_25974_test_t3
#     - pab1_last_loss_147_train_t3.txt
#     - pab1_last_val_lost_147_train_t3.txt
#     - pab1_pred_147_train_t3.txt
#     - pab1_best_targets_147_train_t3.txt
# - ube4b_MLformat_200_train_27447_test_t1
#     - ube4b_last_loss_200_train.txt
#     - ube4b_last_val_lost_200_train.txt
#     - ube4b_pred_200_train.txt
#     - ube4b_best_targets_200_train.txt
# - ube4b_MLformat_200_train_27447_test_t2
#     - ube4b_last_loss_200_train_t2.txt
#     - ube4b_last_val_lost_200_train_t2.txt
#     - ube4b_pred_200_train_t2.txt
#     - ube4b_best_targets_200_train_t2.txt
# - ube4b_MLformat_200_train_27447_test_t3
#     - ube4b_last_loss_200_train_t3.txt
#     - ube4b_last_val_lost_200_train_t3.txt
#     - ube4b_pred_200_train_t3.txt
#     - ube4b_best_targets_200_train_t3.txt
# - avgfp_MLformat_465_train_19458_test_t1
#     - avgfp_last_loss_465_train.txt
#     - avgfp_last_val_lost_465_train.txt
#     - avgfp_pred_465_train.txt
#     - avgfp_best_targets_465_train.txt
# - avgfp_MLformat_465_train_19458_test_t2
#     - avgfp_last_loss_465_train_t2.txt
#     - avgfp_last_val_lost_465_train_t2.txt
#     - avgfp_pred_465_train_t2.txt
#     - avgfp_best_targets_465_train_t2.txt
# - avgfp_MLformat_465_train_19458_test_t3
#     - avgfp_last_loss_465_train_t3.txt
#     - avgfp_last_val_lost_465_train_t3.txt
#     - avgfp_pred_465_train_t3.txt
#     - avgfp_best_targets_465_train_t3.txt
# - gb1_MLformat_110_train_12056_test_t1.txt
#     - gb1_last_loss_110_train_t3.txt
#     - gb1_last_val_lost_110_train_t3.txt
#     - gb1_pred_110_train_t3.txt
#     - gb1_best_targets_110_train_t3.txt

# %% [markdown]
# - nuclease_MLformat_453_train_615_test_t1
#     - nuclease_last_loss_453_train.txt
#     - nuclease_last_val_lost_453_train.txt
#     - nuclease_pred_453_train.txt
#     - nuclease_best_targets_453_train.txt
# - nuclease_MLformat_453_train_615_test_t2
#     - nuclease_last_loss_453_train_t2.txt
#     - nuclease_last_val_lost_453_train_t2.txt
#     - nuclease_pred_453_train_t2.txt
#     - nuclease_best_targets_453_train_t2.txt
# - nuclease_MLformat_453_train_615_test_t3
#     - nuclease_last_loss_453_train_t3.txt
#     - nuclease_last_val_lost_453_train_t3.txt
#     - nuclease_pred_453_train_t3.txt
#     - nuclease_best_targets_453_train_t3.txt

# %% [markdown]
# - glucokinase_MLformat_912_train_7612_test_t1
#     - glucokinase_last_loss_453_train.txt
#     - glucokinase_last_val_lost_453_train.txt
#     - glucokinase_pred_453_train.txt
#     - glucokinase_best_targets_453_train.txt
# - glucokinase_MLformat_912_train_7612_test_t2
#     - glucokinase_last_loss_453_train_t2.txt
#     - glucokinase_last_val_lost_453_train_t2.txt
#     - glucokinase_pred_453_train_t2.txt
#     - glucokinase_best_targets_453_train_t2.txt
# - glucokinase_MLformat_912_train_7612_test_t3
#     - glucokinase_last_loss_453_train_t3.txt
#     - glucokinase_last_val_lost_453_train_t3.txt
#     - glucokinase_pred_453_train_t3.txt
#     - glucokinase_best_targets_453_train_t3.txt

# %% [markdown]
# - pro_1be9_MLformat_235_train_1317_test_t1
#     - pro_1be9_last_loss_453_train.txt
#     - pro_1be9_last_val_lost_453_train.txt
#     - pro_1be9_pred_453_train.txt
#     - pro_1be9_best_targets_453_train.txt
# - pro_1be9_MLformat_235_train_1317_test_t2
#     - pro_1be9_last_loss_453_train_t2.txt
#     - pro_1be9_last_val_lost_453_train_t2.txt
#     - pro_1be9_pred_453_train_t2.txt
#     - pro_1be9_best_targets_453_train_t2.txt
# - pro_1be9_MLformat_235_train_1317_test_t3
#     - pro_1be9_last_loss_453_train_t3.txt
#     - pro_1be9_last_val_lost_453_train_t3.txt
#     - pro_1be9_pred_453_train_t3.txt
#     - pro_1be9_best_targets_453_train_t3.txt

# %% [markdown]
# - pro_1nd4_MLformat_235_train_3979_test_t1
#     - pro_1nd4_last_loss_1000_train.txt
#     - pro_1nd4_last_val_lost_1000_train.txt
#     - pro_1nd4_pred_1000_train.txt
#     - pro_1nd4_best_targets_1000_train.txt
# - pro_1nd4_MLformat_235_train_3979_test_t2
#     - pro_1nd4_last_loss_1000_train_t2.txt
#     - pro_1nd4_last_val_lost_1000_train_t2.txt
#     - pro_1nd4_pred_1000_train_t2.txt
#     - pro_1nd4_best_targets_1000_train_t2.txt
# - pro_1nd4_MLformat_235_train_3979_test_t3
#     - pro_1nd4_last_loss_1000_train_t3.txt
#     - pro_1nd4_last_val_lost_1000_train_t3.txt
#     - pro_1nd4_pred_1000_train_t3.txt
#     - pro_1nd4_best_targets_1000_train_t3.txt

# %% [markdown]
# - pro_4bz3_MLformat_908_train_3631_test_t1
#     - pro_4bz3_last_loss_453_train.txt
#     - pro_4bz3_last_val_lost_453_train.txt
#     - pro_4bz3_pred_453_train.txt
#     - pro_4bz3_best_targets_453_train.txt
# - pro_4bz3_MLformat_908_train_3631_test_t2
#     - pro_4bz3_last_loss_453_train_t2.txt
#     - pro_4bz3_last_val_lost_453_train_t2.txt
#     - pro_4bz3_pred_453_train_t2.txt
#     - pro_4bz3_best_targets_453_train_t2.txt
# - pro_4bz3_MLformat_908_train_3631_test_t3
#     - pro_4bz3_last_loss_453_train_t3.txt
#     - pro_4bz3_last_val_lost_453_train_t3.txt
#     - pro_4bz3_pred_453_train_t3.txt
#     - pro_4bz3_best_targets_453_train_t3.txt

# %% [markdown]
# - pro_3dqw_MLformat_2170_train_1080_test_t1
#     - pro_3dqw_last_loss_453_train.txt
#     - pro_3dqw_last_val_lost_453_train.txt
#     - pro_3dqw_pred_453_train.txt
#     - pro_3dqw_best_targets_453_train.txt
# - pro_3dqw_MLformat_2170_train_1080_test_t2
#     - pro_3dqw_last_loss_453_train_t2.txt
#     - pro_3dqw_last_val_lost_453_train_t2.txt
#     - pro_3dqw_pred_453_train_t2.txt
#     - pro_3dqw_best_targets_453_train_t2.txt
# - pro_3dqw_MLformat_2170_train_1080_test_t3
#     - pro_3dqw_last_loss_453_train_t3.txt
#     - pro_3dqw_last_val_lost_453_train_t3.txt
#     - pro_3dqw_pred_453_train_t3.txt
#     - pro_3dqw_best_targets_453_train_t3.txt

# %% [markdown]
# ### Testing on Alpha Helices and Beta Sheets (2880 vals)

# %% [markdown]
# **Bgl3**

# %% [markdown]
# - In alpha helices: Pearson r (p): (**0.44114971239752243**, 7.905995382169397e-29)

# %% [markdown]
# - In alpha helices: Pearson r (p): (**0.5134073828957915**, 4.716095028298254e-40)

# %% [markdown]
# - In alpha helices: Pearson r (p): (**0.46612786213039215**, 2.0745666636663783e-32)

# %% [markdown]
# - In beta sheets (**800** vals): Pearson r (p): (**0.4562096730267876**, 1.338916380824598e-09)

# %% [markdown]
# **Ube4b**

# %% [markdown]
# - In alpha helices: Pearson r (p): (**0.4734185258502019**, 1.6394418815340077e-33)

# %% [markdown]
# - In alpha helices: Pearson r (p): (**0.4552006352845071**, 8.31803764957109e-31)

# %% [markdown]
# - In alpha helices: Pearson r (p): (**0.4715480508362312**, 3.162401820068704e-33)

# %% [markdown]
# - In beta sheets (**800** vals): Pearson r (p): (**0.6554555081957963**, 5.232527269357708e-21)

# %% [markdown]
# - In beta sheets (**800** vals): Pearson r (p): (**0.6805885064169128**, 4.179176667256575e-23)
